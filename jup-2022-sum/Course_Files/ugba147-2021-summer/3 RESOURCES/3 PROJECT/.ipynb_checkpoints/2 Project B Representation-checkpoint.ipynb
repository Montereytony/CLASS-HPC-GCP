# %% [markdown]
# # Project Part B: Representation
#
# ![](banner_project.jpg)

# %%
analyst = "Firstname Lastname" # Replace this with your name

# %%
f = "setup.R"; for (i in 1:10) { if (file.exists(f)) break else f = paste0("../", f) }; source(f)
options(repr.matrix.max.rows=674)
options(repr.matrix.max.cols=200)
update_geom_defaults("point", list(size=1))
# Out:
# <p style="text-align:center; font-size:10px;">
# .................................................... start of document ....................................................
# </p>

# %% [markdown]
# ## Directions

# %% [markdown]
# ### Objective
#
# Transform the representation of a dataset about public company fundamentals.  Later, use the transformed dataset along with additional analysis to recommend a portfolio of 12 company investments that maximizes 12-month return of an overall \$1,000,000 investment.

# %% [markdown]
# ### Approach
#
# Retrieve a public company fundamentals dataset comprising thousands of US companies from quarters 1, 2, 3, and 4 of year 2017 + company stock price data for those companies from quarter 4 of year 2018.
#
# Transform the dataset representation to capture all information about any single company in a single observation.
#
# Additionally transform the dataset representation using variable filtration, imputation, principal component analysis, and other methods.

# %% [markdown]
# ## Data
#
# _<< Discuss this data retrieval. >>_

# %%
# Retrieve "My Primary Data.csv"
data = read.csv("My Primary Data.csv", header=TRUE)

# Present a few rows ...
data[1:2,]
# Out:
#   gvkey tic conm                        datadate.q1 fyearq.q1 fqtr.q1 fyr.q1
# 1 1004  AIR AAR CORP                    02/28/2017  2016      3        5
# 2 1045  AAL AMERICAN AIRLINES GROUP INC 03/31/2017  2017      1       12
#   indfmt.q1 consol.q1 popsrc.q1 datafmt.q1 cusip.q1  acctchgq.q1 acctstdq.q1
# 1 INDL      C         D         STD        000361105             DS
# 2 INDL      C         D         STD        02376R102             DS
#   adrrq.q1 ajexq.q1 ajpq.q1 bsprq.q1 compstq.q1 curcdq.q1 curncdq.q1 currtrq.q1
# 1 NA       1        1                AZ         USD       USD        1
# 2 NA       1        1                AC         USD       USD        1
#   curuscnq.q1 datacqtr.q1 datafqtr.q1 finalq.q1 ogmq.q1 rp.q1 scfq.q1 srcq.q1
# 1 NA          2017Q1      2016Q3      Y                 Q     7       5
# 2 NA          2017Q1      2017Q1      Y                 Q     7       5
#   staltq.q1 updq.q1 apdedateq.q1 fdateq.q1  pdateq.q1  rdq.q1     acchgq.q1
# 1           3       02/28/2017   03/23/2017 03/21/2017 03/21/2017 0
# 2           3       03/31/2017   04/27/2017            04/27/2017 0
#   acomincq.q1 acoq.q1 actq.q1 altoq.q1 ancq.q1 anoq.q1 aociderglq.q1
# 1   -46.4      28       893.1   90.5     609   NA      0
# 2 -5097.0     856     10626.0 3383.0   42001    0      0
#   aociotherq.q1 aocipenq.q1 aocisecglq.q1 aol2q.q1 aoq.q1 apq.q1 aqaq.q1
# 1    0            -42.5     0               NA      248.5  194.6 NA
# 2 -669          -4428.0     0             6145     9710.0 1882.0 NA
#   aqdq.q1 aqepsq.q1 aqpl1q.q1 aqpq.q1 arcedq.q1 arceepsq.q1 arceq.q1 atq.q1
# 1 NA      NA         NA       NA      NA        NA          NA        1502.1
# 2 NA      NA        700       NA      NA        NA          NA       52627.0
#   aul3q.q1 billexceq.q1 capr1q.q1 capr2q.q1 capr3q.q1 capsftq.q1 capsq.q1
# 1 NA       NA           NA        NA        NA        NA          457.3
# 2  0       NA           NA        NA        NA        NA         6726.0
#   ceiexbillq.q1 ceqq.q1 cheq.q1 chq.q1 cibegniq.q1 cicurrq.q1 ciderglq.q1
# 1 NA             885.7    10.1   10.1   13.7       -0.2       0
# 2 NA            3457.0  7219.0  374.0  340.0        0.0       0
#   cimiiq.q1 ciotherq.q1 cipenq.q1 ciq.q1 cisecglq.q1 citotalq.q1 cogsq.q1
# 1 0         0             0.3      13.8  0            13.8        340.7
# 2 0         0           -14.0     326.0  0           326.0       6774.0
#   csh12q.q1 cshfd12.q1 cshfdq.q1 cshiq.q1 cshopq.q1 cshoq.q1 cshprq.q1
# 1  33.925    34.2750    34.200    45.17    0.052     34.324   33.700
# 2 526.722   530.1763   507.797   495.75   11.677    495.750  503.902
#   cstkcvq.q1 cstkeq.q1 cstkq.q1 dcomq.q1 dd1q.q1 deracq.q1 deraltq.q1
# 1 1.00       -0.1      45.2     0           2    NA        NA
# 2 0.01        0.0       5.0     0        1714    NA        NA
#   derhedglq.q1 derlcq.q1 derlltq.q1 diladq.q1 dilavq.q1 dlcq.q1 ... stkcpay.q4
# 1 NA           NA        NA         0          14.3        2    ... NA
# 2 NA           NA        NA         0         340.0     1714    ... NA
#   tdcy.q4 tfvcey.q4 tiey.q4 tiiy.q4 tsafcy.q4 txachy.q4 txbcofy.q4 txbcoy.q4
# 1 NA      NA        NA      NA      NA        NA        0          0
# 2 NA      NA        NA      NA      NA         0        0          0
#   txdcy.q4 txdiy.q4 txpdy.q4 txty.q4 txwy.q4 uaolochy.q4 udfccy.q4 udvpy.q4
# 1  -22.1     NA     14.7       11.2  0       NA          NA        NA
# 2 1141.0   2089     20.0     2113.0  0       NA          NA        NA
#   ufretsdy.q4 ugiy.q4 uniamiy.q4 unopincy.q4 unwccy.q4 uoisy.q4 updvpy.q4
# 1 NA          NA      NA         NA          NA        NA       NA
# 2 NA          NA      NA         NA          NA        NA       NA
#   uptacy.q4 uspiy.q4 ustdncy.q4 usubdvpy.q4 utfdocy.q4 utfoscy.q4 utmey.q4
# 1 NA        NA       NA         NA          NA         NA         NA
# 2 NA        NA       NA         NA          NA         NA         NA
#   uwkcapcy.q4 wcapchy.q4 wcapcy.q4 wday.q4 wddy.q4 wdepsy.q4 wdpy.q4 xidocy.q4
# 1 NA          NA         NA        NA      NA      NA        NA      -1.2
# 2 NA          NA         NA        NA      NA      NA        NA       0.0
#   xidoy.q4 xinty.q4 xiy.q4 xopry.q4 xoptdqpy.q4 xoptdy.q4 xoptepsqpy.q4
# 1 -36.2       3.6   0        758.7  NA          NA        NA
# 2   0.0    1102.0   0      35640.0  NA          NA        NA
#   xoptepsy.q4 xoptqpy.q4 xopty.q4 xrdy.q4 xsgay.q4 exchg.q4 cik.q4 costat.q4
# 1 NA          NA         NA       NA        93.3   11       1750   A
# 2 NA          NA         NA       NA      7240.0   14       6201   A
#   fic.q4 cshtrq.q4 dvpspq.q4 dvpsxq.q4 mkvaltq.q4 prccq.q4 prchq.q4 prclq.q4
# 1 USA     13354306 0.075     0.075      1444.032  41.58    41.94    34.25
# 2 USA    270496454 0.100     0.100     24740.681  52.03    53.74    45.27
#   adjex.q4 add1.q4                                  add2.q4 add3.q4 add4.q4
# 1 1        One AAR Place, 1100 North Wood Dale Road         NA      NA
# 2 1        1 Skyview Drive                                  NA      NA
#   addzip.q4
# 1 60191
# 2 76155
#   busdesc.q4
# 1 AAR Corp. provides products and services to commercial aviation, government, and defense markets worldwide. The company operates in two segments, Aviation Services and Expeditionary Services.
# 2 American Airlines Group Inc., through its subsidiaries, operates as a network air carrier. It provides scheduled air transportation services for passengers and cargo. As of December 31, 2018, the company operated a mainline fleet of 956 aircraft.
#   city.q4    conml.q4                    county.q4 dlrsn.q4 ein.q4
# 1 Wood Dale  AAR Corp                              NA       36-2334820
# 2 Fort Worth American Airlines Group Inc           NA       75-1825172
#   fax.q4       fyrc.q4 ggroup.q4 gind.q4 gsector.q4 gsubind.q4 idbflag.q4
# 1 630-227-2039  5      2010      201010  20         20101010   D
# 2              12      2030      203020  20         20302010   B
#   incorp.q4 loc.q4 naics.q4 phone.q4     prican.q4 prirow.q4 priusa.q4 sic.q4
# 1 DE        USA    423860   630-227-2000                     1         5080
# 2 DE        USA    481111   817-963-1234                     4         4512
#   spcindcd.q4 spcseccd.q4 spcsrc.q4 state.q4 stko.q4 weburl.q4       dldte.q4
# 1 110         925         B         IL       0       www.aarcorp.com NA
# 2 605         600         B-        TX       0       www.aa.com      NA
#   ipodate.q4 prccq growth      big_growth
# 1 01/01/1988 43.69  0.05074555 NO
# 2            32.11 -0.38285604 NO

# %%
# Identify which variables can later be used as
# outcome variables and which can be used as predictor variables.
# Out:
# <table><tr><td style="background-color:white; vertical-align:top; padding-right:40px;"><table>
#  <thead>
#   <tr>
#    <th style="text-align:right;background-color: #FFFFFF !important;"> outvars </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:right;"> prccq </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> growth </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> big_growth </td>
#   </tr>
# </tbody>
# </table></td><td style="background-color:white; vertical-align:top;"><table>
#  <thead>
#   <tr>
#    <th style="text-align:right;background-color: #FFFFFF !important;"> prevars (first few) </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:right;"> gvkey </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> tic </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> conm </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> datadate.q1 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> fyearq.q1 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> fqtr.q1 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> fyr.q1 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> indfmt.q1 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> consol.q1 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> popsrc.q1 </td>
#   </tr>
# </tbody>
# </table></td></tr></table>

# %% [markdown]
# ## Transform Representation of Data
#
# _<< Discuss this new representation of data. >>_

# %% [markdown]
# ### Variable Filtration

# %%
# Filter the data to include only predictor variables with at least 95% non-missing values. 
# Keep the variable names from the resulting dataset for later use.
# How many observations and variables in the resulting dataset?
#
# You can use the var_info.na_count() function.
# Out:
# <table>
# <caption><center><font color="black"><b>data after variable filtration</b></font></center></caption>
#  <thead>
#   <tr>
#    <th style="text-align:right;background-color: #FFFFFF !important;"> observations </th>
#    <th style="text-align:right;background-color: #FFFFFF !important;"> variables </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:right;"> 4305 </td>
#    <td style="text-align:right;"> 239 </td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# ### Imputation

# %%
# Impute missing data:
# for each numeric variable, use the mean of non-missing values;
# for each non-numeric variable, use the mode of non-missing values.
# Keep the impute values used for each variabkle for future use.
#
# You can use the get_impute() and impute() functions.
# get_impute(data) provides a vector of means and modes, one for each variable of data.
# impute(data) provides a table like data, but imputed with means and modes.
# Out:
# <table>
# <caption><center><font color="black"><b>data after imputation</b></font></center></caption>
#  <thead>
#   <tr>
#    <th style="text-align:right;background-color: #FFFFFF !important;"> observations </th>
#    <th style="text-align:right;background-color: #FFFFFF !important;"> variables </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:right;"> 4305 </td>
#    <td style="text-align:right;"> 239 </td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# ### Principal Component Analysis

# %%
# For principal component analysis, filter the data to include only numeric (including integer)
# variables with non-zero variance.
# How many observations and variables?
# Out:
# <table>
# <caption><center><font color="black"><b>data with only numeric and integer variables</b></font></center></caption>
#  <thead>
#   <tr>
#    <th style="text-align:right;background-color: #FFFFFF !important;"> observations </th>
#    <th style="text-align:right;background-color: #FFFFFF !important;"> variables </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:right;"> 4305 </td>
#    <td style="text-align:right;"> 151 </td>
#   </tr>
# </tbody>
# </table>
# <table>
# <caption><center><font color="black"><b>data after removing zero-variance variables</b></font></center></caption>
#  <thead>
#   <tr>
#    <th style="text-align:right;background-color: #FFFFFF !important;"> observations </th>
#    <th style="text-align:right;background-color: #FFFFFF !important;"> variables </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:right;"> 4305 </td>
#    <td style="text-align:right;"> 151 </td>
#   </tr>
# </tbody>
# </table>

# %%
# Perform a principal component analysis on the numeric and integer variables with non-zero variance
# (use scale=TRUE).
# Keep the centroids and weight matrix for later use.
# Present the first few observations represented as principal components.
# For some principal components, +/- may be different than as shown in the expected output. If so,
# then multiply by -1 to adjust.
# Out:
#      PC1       PC2       PC3         PC4        PC5         PC6
# [1,]  1.409764 0.2124544 -0.18735809 -1.3446137 -0.03652073 -5.0250338
# [2,] -2.809314 0.2246363  1.43661206 -3.2326072  0.36864597  1.4262023
# [3,]  1.524722 0.4396434 -0.16785608 -0.4733925  0.66529296  0.3661023
# [4,]  1.573669 0.6384403  0.01227541  1.2308994  0.05097253  0.6109604
# [5,]  1.281265 0.4529129  0.09293832 -0.8541629 -0.32210027 -4.7346676
#      PC7        PC8        PC9         PC10       PC11        PC12
# [1,]  0.8071181  0.2308762 -0.41721177  1.4908250 -0.39944188 -0.5379293
# [2,]  2.0046301 -1.6756734 -1.57337115  0.3330458  1.30857749 -0.5722713
# [3,]  2.2428475  1.3492993 -0.06127394 -0.0644994  0.07525768 -0.1219964
# [4,] -0.7640124 -0.7708479 -0.13041213  1.1817421 -0.38747683 -0.3707853
# [5,] -1.0982939 -0.7556450  0.18329434  1.5742726 -0.34936226  0.3256910
#      PC13       PC14      PC15        PC16       PC17        PC18
# [1,]  0.5058319 0.2376358  0.89752680 -0.4677236  0.30833984  0.5156390
# [2,]  0.8129528 1.0506235  0.07336061  0.3887728  0.58111711  0.2253818
# [3,]  0.4036427 0.2399168 -0.43684536  0.2696851  0.06149784  0.1147493
# [4,] -0.2987798 0.6561800  0.81396914 -0.2307742  0.31856392  0.1534360
# [5,] -1.6853485 0.2919847 -0.52163295  0.1301963 -0.11599679 -0.4036542
#      PC19        PC20       PC21       PC22        PC23       PC24
# [1,]  0.15023757 -0.2972639  0.4994577 -0.09895600 -1.9734201  0.64193587
# [2,]  0.01106485 -1.1777649  0.8164647  0.07447442 -0.5922569 -0.01669591
# [3,]  0.17513809 -0.4814173  0.7812042 -0.24896559 -0.4834659  0.12149964
# [4,] -0.27548462 -0.1865421  0.1837970 -0.02734118 -0.4362197  0.20837916
# [5,]  0.33800430  0.7317709 -0.1859148 -0.02609676 -2.1003249  1.30118401
#      PC25       PC26          PC27        PC28      PC29        PC30
# [1,]  0.1415775 -0.2177932068 -0.60180089 0.6090365  0.59423068  0.50641541
# [2,] -0.9119773 -1.1849859765 -1.43007468 0.4663901  0.03150418  0.84585275
# [3,]  0.1350113 -0.0009309213 -1.16926501 0.7544172  0.77975402  0.67894087
# [4,] -0.0854137 -0.1450627376 -0.23313607 0.2449853  0.10349826  0.08396946
# [5,]  0.2738841 -0.5311304082 -0.09695945 0.3444688 -0.01204730 -0.76927229
#      PC31       PC32        PC33        PC34        PC35        PC36
# [1,] -0.6464006 -0.05022805 -0.56653910  0.30062391 -0.08747514  0.24654698
# [2,] -0.6697412 -0.11061311 -0.60071183  0.02753408 -0.37497389  0.40908541
# [3,] -0.3293648 -0.03568539 -0.43727205  0.44407616  0.10852840  0.26764705
# [4,] -0.1060369  0.02305423 -0.16785912  0.04282673  0.09998420 -0.03190628
# [5,]  0.1760990 -0.03156092  0.05293336 -0.06978396 -0.10921976 -0.08354800
#      PC37         PC38         PC39        PC40        PC41       PC42
#      PC144            PC145         PC146         PC147         PC148
# [1,] -0.0000010500520 -3.861705e-15  1.720750e-17 -1.174267e-15  3.939605e-15
# [2,] -0.0000003744207  1.952614e-15  1.358068e-15 -5.466103e-16  2.524768e-15
# [3,]  0.0000016171422  6.289170e-16 -4.642533e-16  1.620074e-16  6.190812e-16
# [4,] -0.0000006587179  1.315499e-15 -3.289373e-15  1.026201e-15 -6.827307e-16
# [5,] -0.0000003238616 -7.487845e-16 -3.149098e-16 -6.142984e-17 -1.494738e-15
#      PC149         PC150         PC151
# [1,] -6.600672e-16  1.288657e-15  1.296993e-15
# [2,] -3.072414e-17  9.252646e-16  4.291123e-16
# [3,] -3.778674e-16  2.136356e-16  4.772342e-16
# [4,]  7.391830e-17 -1.098190e-16 -1.452576e-16
# [5,] -2.952654e-16 -4.766597e-16 -3.629845e-16

# %%
# Present a bar chart to visualize the variance of the first 20 principal components.
#
# You can use the var_info.var() function.
# Out:
# plot without title

# %%
# Present a 2D scatterplot to visualize PC1 vs PC2 vs big_growth
# (for -100≤PC1≤10 on horizontal axis, -50≤PC2≤100 on vertical axis, and big_growth color-coded).
# Out:
# plot without title

# %% [markdown]
# ### Transform the Data

# %%
# Change the representation of the data:
#   The first 3 columns are gvkey, tic, and conm; these are predictor variables
#   The next 3 columns are PC1, PC2, and PC3; these are predictor variables
#   The next 3 columns are prccq, growth, and big_growth; these are outcome variables
# Keep the names of the predictor variables for later use.
#
# How many observations and variables?
# How many predictor variables?
# How many outcome variables? 
# Present the first few observations of the resulting dataset.
# Out:
#   observations variables
# 1 4305         9
#   length.prevars. length.outvars.
# 1 6               3
#   gvkey tic  conm                         PC1        PC2        PC3
# 1 1004  AIR  AAR CORP                      1.4097638  0.2124544 -0.18735809
# 2 1045  AAL  AMERICAN AIRLINES GROUP INC  -2.8093139  0.2246363  1.43661206
# 3 1050  CECE CECO ENVIRONMENTAL CORP       1.5247216  0.4396434 -0.16785608
# 4 1062  ASA  ASA GOLD AND PRECIOUS METALS  1.5736687  0.6384403  0.01227541
# 5 1072  AVX  AVX CORP                      1.2812646  0.4529129  0.09293832
# 6 1075  PNW  PINNACLE WEST CAPITAL CORP    0.3697622 -0.4860613 -0.01283639
#   prccq growth        big_growth
# 1 43.69  0.0507455507 NO
# 2 32.11 -0.3828560446 NO
# 3  6.75  0.3157894737 YES
# 4  8.66 -0.2164739518 NO
# 5 15.25 -0.1184971098 NO
# 6 85.20  0.0002347969 NO

# %% [markdown]
# ### Store Transformed Data & Transformation Meta-Data

# %%
# Store the transformed data (4305 observations, 8 variables)
write.csv(data, "My Data.csv", row.names=FALSE)

# %%
# Store the variable names of the filtered data (239 predictor variable names)
saveRDS(cn, "My Filter.rds")

# %%
# Store the imputation values (239 means and modes)
saveRDS(ml, "My Imputation.rds")

# %%
# Store the PCA centroids and weight matrix
saveRDS(pc, "My PC.rds")

# %%
# Store the predictor variable names of the transformed data (6 predictor variable names)
saveRDS(prevars, "My Predictors.rds")

# %% [markdown]
# <font size=1;>
# <p style="text-align: left;">
# Copyright (c) Berkeley Data Analytics Group, LLC
# <span style="float: right;">
# Document revised December 28, 2020
# </span>
# </p>
# </font>
