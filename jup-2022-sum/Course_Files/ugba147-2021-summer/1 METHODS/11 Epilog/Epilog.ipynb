# %% [markdown]
# # Epilog

# %% [markdown]
# ![](banner_introduction.jpg)

# %%
f = "setup.R"; for (i in 1:10) { if (file.exists(f)) break else f = paste0("../", f) }; source(f)
# Out:
# <p style="text-align:center; font-size:10px;">
# .................................................... start of document ....................................................
# </p>

# %% [markdown]
# ## Data-to-Decision Methodology

# %% [markdown]
# ![](d2d_process.jpg)

# %% [markdown]
# ## What You Know

# %%
options(warn=-1)

# Load some required functions
library(ggplot2,     verbose=FALSE, warn.conflicts=FALSE, quietly=TRUE)
library(ggwordcloud, verbose=FALSE, warn.conflicts=FALSE, quietly=TRUE)

restore = list(repr.plot.width=8, repr.plot.height=4)
options(restore)

# Set some visualization constants
PALETTE = c("#00A9FF", "#F8766D", "#7CAE00", "#C77CFF", "#CD9600", "#00BE67", "#FF61CC", "#00BFC4")

data = c("business analytics"=15,
         "decisions"=25,
         "data"=25,
         "R"=15,
         "Jupyter"=10,
         "methods"=5,
         "machine learning"=5,
         "data mining"=5,
         "descriptive analytics"=5,
         "predictive analytics"=5,
         "business applications"=5,
         "data-driven decisions"=5,
         "biases"=5,
         "risk profiles"=5,
         "methodology for data-driven decisions"=5,
         "data selection"=10,
         "data frame"=5,
         "rendered variables"=5,
         "descriptive statistics"=10,
         "cross-tabulation"=5,
         "data visualization"=10,
         "scatterplot"=5,
         "barplot"=5,
         "lineplot"=5,
         "histogram"=5,
         "kernel density estimation"=10,
         "probability density function"=5,
         "balancing"=5,
         "alignment"=5,
         "imputation"=5,
         "principal component analysis"=10,
         "cluster analysis"=15,
         "hierarchical agglomeration"=5,
         "k-means"=5,
         "expectation maximization"=10,
         "gaussian mixture model"=10,
         "classification"=15,
         "confusion matrix"=15,
         "business value"=10,
         "regression"=10,
         "model evaluation"=5,
         "hold-out"=5,
         "cross-validation"=15,
         "logistic regression"=5,
         "k-nearest neighbor"=5,
         "decision tree"=5,
         "naive bayes"=15,
         "support vector machine"=15,
         "perceptron"=5,
         "neural network"=15,
         "linear regression"=15,
         "multi-class classification"=10,
         "ensemble meta-methods"=10,
         "bootstrap aggregating"=5,
         "boosting"=5,
         "stacking"=5,
         "random forest"=5,
         "model tuning"=10,
         "feature selection"=5,
         "hyper-parameter value selection"=5,
         "time series"=5,
         "text mining"=5)

data = data.frame(label=names(data), size=data, row.names=NULL)

set.seed(2)
ggwordcloud2(data, size=0.8, minRotation=2*pi, maxRotation=2*pi, rotateRatio=0.35, ellipticity=0.9, shape="square")
# Out:
# plot without title

# %% [markdown]
# ## Words of Wisdom

# %% [markdown]
# <table style="width:70%">
#   <tr>
#       <td><div align="center"><img src="descartes.jpg"></div></td>
#     <td><div align="left"><font size="3">I hope that posterity will judge me kindly, not only as to the things which I have explained, but also to those which I have intentionally omitted so as to leave to others the pleasure of discovery.<br><br>- Rene Descartes</font></div></td>
#   </tr>
# </table>

# %% [markdown]
# ## May Your Curiosity Never Be Satisfied
#
# **Please send me emails occasionally to let me know how your studies and careers are progressing rhuntsinger@berkeley.edu**

# %% [markdown]
# <p style="text-align:left; font-size:10px;">
# Copyright (c) Berkeley Data Analytics Group, LLC
# <span style="float:right;">
# Document revised July 1, 2020
# </span>
# </p>
