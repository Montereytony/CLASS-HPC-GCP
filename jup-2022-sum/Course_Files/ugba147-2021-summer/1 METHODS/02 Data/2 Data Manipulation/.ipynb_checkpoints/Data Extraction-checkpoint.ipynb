# %% [markdown]
# # Data Manipulation
#
# ![](banner_data_selection.jpg)
#
# _<p style="text-align: center;"> The "Data-O-Matic"!  It slices!  It dices! </p>_

# %%
f = "setup.R"; for (i in 1:10) { if (file.exists(f)) break else f = paste0("../", f) }; source(f)
# Out:
# <p style="text-align:center; font-size:10px;">
# .................................................... start of document ....................................................
# </p>

# %% [markdown]
# ## Introduction
#
# Motivation, context, history, related topics ...

# %% [markdown]
# ## Terms

# %% [markdown]
# | IT                                  | Statistics     | Other Fields                        | Example                    |
# |------------------------------------ | -------------- | ----------------------------------- | -------------------------- |
# | database<br> table                  | population     | dataset<br> dataframe               | ![](table.jpg)             |
# | record #                            | observation #  | row #<br> row name                  | ![](row_number.jpg)        |
# | row<br> record                      | observation    | datapoint                           | ![](row.jpg)               |
# | column name                         | variable       | feature<br> attribute<br> dimension | ![](column_name.jpg)       |
# | column                              | distribution   | vector                              | ![](column.jpg)            |
# | -                                   | distribution   | vector                              | ![](vector-vertical.jpg)   |
# | -                                   | distribution   | vector                              | ![](vector-horizontal.jpg) |
# | value<br> cell                      | value          | datum<br> vector                    | ![](value.jpg)             |
# | slice<br> horizontal slice<br> dice | sample         | subset                              | ![](sample.jpg)            |
# | slice<br> vertical slice            | -              | -                                   | ![](slice.jpg)             |

# %% [markdown]
# ## Data
#
# Consider the following pedagogical dataset called `data`.

# %%
data = read.csv("High-Tech Stocks.csv", header=TRUE)
data
# Out:
#     Date     Apple.Return Dell.Return IBM.Return  Microsoft.Return
# 1   1990.042 -0.035461    -0.15909090  0.04780877  0.06321839
# 2   1990.125  0.003235     0.35135135  0.06550063  0.06756756
# 3   1990.208  0.183824     0.22000000  0.02166065  0.12151898
# 4   1990.292 -0.021739     0.11475410  0.02709069  0.04740406
# 5   1990.375  0.050413     0.29411766  0.11201835  0.25862068
# 6   1990.458  0.084848     0.14772727 -0.02083330  0.04109589
# 7   1990.542 -0.061453    -0.06930690 -0.05106380 -0.12500000
# 8   1990.625 -0.116429     0.00000000 -0.07547090 -0.07518800
# 9   1990.708 -0.216216    -0.25531910  0.04417178  0.02439024
# 10  1990.792  0.060345     0.21428572 -0.00940070  0.01190476
# 11  1990.875  0.199024     0.23529412  0.08977462  0.13333334
# 12  1990.958  0.170068     0.40952381 -0.00550060  0.04152249
# 13  1991.042  0.290698     0.22297297  0.12168141  0.30398670
# 14  1991.125  0.033694     0.11602210  0.02532544  0.05732484
# 15  1991.208  0.187773     0.12871288 -0.11553400  0.02289157
# 16  1991.292 -0.191176    -0.17982460 -0.09549940 -0.06713780
# 17  1991.375 -0.143273     0.05882353  0.04208738  0.10858586
# 18  1991.458 -0.117021    -0.01010100 -0.08480570 -0.06890660
# 19  1991.542  0.114458     0.17346939  0.04247104  0.07889909
# 20  1991.625  0.148541     0.13478261 -0.03125930  0.15986395
# 21  1991.708 -0.066038     0.02298851  0.06967742  0.04398827
# 22  1991.792  0.040404    -0.25468160 -0.05186970  0.05477528
# 23  1991.875 -0.012233    -0.05527640 -0.04620870  0.03595207
# 24   89.000    111.250          19911231
# 25   90.000    120.250          19920131
# 26   86.875    123.500          19920228
# 27   83.500    118.500          19920331
# 28   90.750    110.250          19920430
# 29   90.750    121.000          19920529
# 30   97.875     70.000          19920630
# ... ...        ...              ...
# 232 103.21     20.2600          20090428
# 233 106.28     20.8900          20090531
# 234 104.42     23.7700          20090630
# 235 117.93     23.5200          20090731
# 236 118.05     24.6500          20090831
# 237 119.61     25.7200          20090929
# 238 120.61     27.7300          20091031
# 239 126.35     29.4100          20091130
# 240 130.90     30.4800          20091229
# 241 122.39     28.1800          20100131
# 242 127.16     28.6700          20100228
# 243 128.25     29.2875          20100331
# 244 129.00     30.5350          20100428
# 245 125.26     25.8000          20100531
# 246 123.48     23.0100          20100630
# 247 128.40     25.8100          20100731
# 248 123.13     23.4650          20100831
# 249 134.14     24.4900          20100929
# 250 143.60     26.6650          20101031
# 251 141.46     25.2575          20101130
# 252 146.76     27.9100          20101229
# 253 162.00     27.7250          20110131
# 254 161.88     26.5800          20110228
# 255 163.07     25.3900          20110331
# 256 170.58     25.9200          20110428
# 257 168.93     25.0100          20110531
# 258 171.55     26.0000          20110630
# 259 181.85     27.4000          20110731
# 260 171.91     26.6000          20110831
# 261 174.87     24.8900          20110929

# %% [markdown]
# ## Index-Based Extraction | Rows

# %% [markdown]
# To inspect all or part of the dataset, we reference the `data` table retrieved earlier.  We indicate which rows and columns of the table we want with `[...]` notation - specific row positions and column positions separated by a comma and enclosed within brackets.  We start counting row positions and column positions at 1.  If we want all rows, then we can leave the row positions blank and all rows will be assumed.  Similarly, if we want all columns, then we can leave the column positions blank and all columns will be assumed.
#
# So, to inspect the 1st row of data, we reference `data[1,]`.  The row position (in this case just 1 row) is 1.  The column positions are blank and so assumed to be all columns.  Note, the comma is required even though we left the column positions blank.  The output is presented as a table with 12 columns, with headings, each with 1 value per column corresponding to the 1st observation in the dataset.

# %%
data[1,]
# Out:
#   Date     Apple.Return Dell.Return IBM.Return Microsoft.Return
# 1 1990.042 -0.035461    -0.1590909  0.04780877 0.06321839
#   Value.weighted.Market.Return SP.500.Return Price..Dell Price..Apple
# 1 -0.070115                    -0.068817     4.625       34
#   Price..IBM Price..Microsoft Calendar.Date
# 1 98.625     92.5             19900131

# %% [markdown]
# To inpect the 5th row of data, we reference `data[5,]`.  The row index (in this case just 1 row) is 5.

# %%
data[5,]
# Out:
#   Date     Apple.Return Dell.Return IBM.Return Microsoft.Return
# 5 1990.375 0.050413     0.2941177   0.1120184  0.2586207
#   Value.weighted.Market.Return SP.500.Return Price..Dell Price..Apple
# 5 0.088936                     0.091989      11          41.25
#   Price..IBM Price..Microsoft Calendar.Date
# 5 120        73               19900531

# %% [markdown]
# To inspect the first 3 rows of data, we reference `data[1:3,]`.  We indicate a sequence of positions with the `:` notation - the left side is the start position, the right side is the stop position.  So, the row positions indicated by `1:3` are 1, 2, and 3.  The output is presented as a table with 12 columns, with headings, each with 3 values per column corresponding to the first 3 observations in the dataset.

# %%
data[1:3,]
# Out:
#   Date     Apple.Return Dell.Return IBM.Return Microsoft.Return
# 1 1990.042 -0.035461    -0.1590909  0.04780877 0.06321839
# 2 1990.125  0.003235     0.3513514  0.06550063 0.06756756
# 3 1990.208  0.183824     0.2200000  0.02166065 0.12151898
#   Value.weighted.Market.Return SP.500.Return Price..Dell Price..Apple
# 1 -0.070115                    -0.068817     4.625       34.00
# 2  0.014901                     0.008539     6.250       34.00
# 3  0.024140                     0.024255     7.625       40.25
#   Price..IBM Price..Microsoft Calendar.Date
# 1  98.625     92.50           19900131
# 2 103.875     98.75           19900228
# 3 106.125    110.75           19900330

# %% [markdown]
# To inspect the 2nd through 5th rows of data, we reference `data[2:5,]`.  The row positions indicated by `2:5` are 2, 3, 4, and 5.

# %%
data[2:5,]
# Out:
#   Date     Apple.Return Dell.Return IBM.Return Microsoft.Return
# 2 1990.125  0.003235    0.3513514   0.06550063 0.06756756
# 3 1990.208  0.183824    0.2200000   0.02166065 0.12151898
# 4 1990.292 -0.021739    0.1147541   0.02709069 0.04740406
# 5 1990.375  0.050413    0.2941177   0.11201835 0.25862068
#   Value.weighted.Market.Return SP.500.Return Price..Dell Price..Apple
# 2  0.014901                     0.008539      6.250      34.000
# 3  0.024140                     0.024255      7.625      40.250
# 4 -0.028286                    -0.026887      8.500      39.375
# 5  0.088936                     0.091989     11.000      41.250
#   Price..IBM Price..Microsoft Calendar.Date
# 2 103.875     98.75           19900228
# 3 106.125    110.75           19900330
# 4 109.000     58.00           19900430
# 5 120.000     73.00           19900531

# %% [markdown]
# To inspect the 1st and 3rd rows of the data, we reference `data[c(1,3),]`.  We indicate a sequence of positions with the `c` function.  So, the row positions described by `c(1,3)` are 1 and 3.  Note, the `:` notation would not be appropriate here, because it does not allow skipped positions.  Note also, it would not be appropriate here to describe the row positions without the `c` function because the row positions would not otherwise be distinguisghable from the column positions.  The output is presented as a table with 12 columns, with headings, each with 2 values per column corresponding to the 1st and 3rd observations in the dataset.

# %%
data[c(1,3),]
# Out:
#   Date     Apple.Return Dell.Return IBM.Return Microsoft.Return
# 1 1990.042 -0.035461    -0.1590909  0.04780877 0.06321839
# 3 1990.208  0.183824     0.2200000  0.02166065 0.12151898
#   Value.weighted.Market.Return SP.500.Return Price..Dell Price..Apple
# 1 -0.070115                    -0.068817     4.625       34.00
# 3  0.024140                     0.024255     7.625       40.25
#   Price..IBM Price..Microsoft Calendar.Date
# 1  98.625     92.50           19900131
# 3 106.125    110.75           19900330

# %% [markdown]
# ## Index-Based Extraction | Rows & Columns

# %% [markdown]
# To inspect the data at the intersection of row 1 and column 2, we reference `data[1,2]`.  Because this references a single value, association with a table is dropped, and the output is presented as single value.

# %%
data[1,2]
# Out:
# [1] -0.035461

# %% [markdown]
# To inspect only the first 5 columns of the 1st row of data, we reference `data[1,1:5]`.

# %%
data[1,1:5]
# Out:
#   Date     Apple.Return Dell.Return IBM.Return Microsoft.Return
# 1 1990.042 -0.035461    -0.1590909  0.04780877 0.06321839

# %% [markdown]
# To inspect only the first 5 columns of the first 3 rows of data, we reference `data[1:3,1:5]`.

# %%
data[1:3,1:5]
# Out:
#   Date     Apple.Return Dell.Return IBM.Return Microsoft.Return
# 1 1990.042 -0.035461    -0.1590909  0.04780877 0.06321839
# 2 1990.125  0.003235     0.3513514  0.06550063 0.06756756
# 3 1990.208  0.183824     0.2200000  0.02166065 0.12151898

# %% [markdown]
# To inspect the first 5 columns and the 7th column of the 2nd and 4th rows of data, we reference `data[c(2,4),c(1:5,7)]`.  Note, the `c` function can take a combination of `:`-style sequences and single positions as parameters.

# %%
data[c(2,4),c(1:5,7)]
# Out:
#   Date     Apple.Return Dell.Return IBM.Return Microsoft.Return SP.500.Return
# 2 1990.125  0.003235    0.3513514   0.06550063 0.06756756        0.008539
# 4 1990.292 -0.021739    0.1147541   0.02709069 0.04740406       -0.026887

# %% [markdown]
# ## Name-Based Extraction | Rows & Columns

# %% [markdown]
# As a sometimes convenient alternative to referencing columns by their positions, we can indicate them by their names.  Note, column names are described as strings and so must each be enclosed within `"..."`.

# %%
data[1,"Apple.Return"]
# Out:
# [1] -0.035461

# %%
data[1,c("Date","Apple.Return","Dell.Return","IBM.Return","Microsoft.Return")]
# Out:
#   Date     Apple.Return Dell.Return IBM.Return Microsoft.Return
# 1 1990.042 -0.035461    -0.1590909  0.04780877 0.06321839

# %%
data[c(1,3),c("Date","Apple.Return","Dell.Return","IBM.Return","Microsoft.Return","SP.500.Return")]
# Out:
#   Date     Apple.Return Dell.Return IBM.Return Microsoft.Return SP.500.Return
# 1 1990.042 -0.035461    -0.1590909  0.04780877 0.06321839       -0.068817
# 3 1990.208  0.183824     0.2200000  0.02166065 0.12151898        0.024255

# %% [markdown]
# ## Name-Based Extraction | Rows & One Column
# Indicate the column by its name using \$ notation.

# %% [markdown]
# As a sometimes convenient alternative to referencing columns using the `[...]` notation, if we want just one column, then we can use the `$` notation - a table name followed by the `$` symbol, followed by a column name, followed by row positions enclosed within `[...]`.
#
# So, to inspect the `Apple.Return` column of the 1st row of data, we reference `data$Apple.Return[1]`.  Note, in this notation, the column name is described not as a string, so it is not enclosed within `"..."`.  Note also, because this references a single value, association with a table is dropped, and the output is presented as single value.  (We cannot force the reference to keep an association with a table.)

# %%
data$Apple.Return[1]
# Out:
# [1] -0.035461

# %% [markdown]
# To inspect the `Apple.Return` column of the 1st 3 rows of data, we reference `data$Apple.Return[1:3]`.  Note, because these reference vectors of values, associations with tables are dropped, and the outputs are presented as vectors. (We cannot force these references to keep associations with tables.)

# %%
data$Apple.Return[1:3]
# Out:
# [1] -0.035461  0.003235  0.183824

# %% [markdown]
# Similarly, to inspect the `Apple.Return` column of the 1st and 3rd rows of data, we reference `data$Apple.Return[c(1,3)]`.

# %%
data$Apple.Return[c(1,3)]
# Out:
# [1] -0.035461  0.183824

# %% [markdown]
# ## Criterion-Based Extraction | Rows

# %% [markdown]
# To inspect the part of the dataset that satisfies a specific criterion, we again use the `[...]` notation, but indicate the rows we want by TRUE/FALSE expressions involving the columns.  (This is similar to, but more general than, Excel's filtering functionality.)
#
# To inspect only rows where the `Date` column value is less than 1991 (i.e., observations from earlier than the year 1991), we reference `data[data$Date < 1991,]`.  The row positions are indicated by the expression `data$Data < 1991` - every value in the `Date` column is compared to 1991, and rows selected accordingly.  The column positions are blank and so assumed to be all columns.

# %%
data[data$Date < 1991,]
# Out:
#    Date     Apple.Return Dell.Return IBM.Return  Microsoft.Return
# 1  1990.042 -0.035461    -0.1590909   0.04780877  0.06321839
# 2  1990.125  0.003235     0.3513514   0.06550063  0.06756756
# 3  1990.208  0.183824     0.2200000   0.02166065  0.12151898
# 4  1990.292 -0.021739     0.1147541   0.02709069  0.04740406
# 5  1990.375  0.050413     0.2941177   0.11201835  0.25862068
# 6  1990.458  0.084848     0.1477273  -0.02083330  0.04109589
# 7  1990.542 -0.061453    -0.0693069  -0.05106380 -0.12500000
# 8  1990.625 -0.116429     0.0000000  -0.07547090 -0.07518800
# 9  1990.708 -0.216216    -0.2553191   0.04417178  0.02439024
# 10 1990.792  0.060345     0.2142857  -0.00940070  0.01190476
# 11 1990.875  0.199024     0.2352941   0.08977462  0.13333334
# 12 1990.958  0.170068     0.4095238  -0.00550060  0.04152249
#    Value.weighted.Market.Return SP.500.Return Price..Dell Price..Apple
# 1  -0.070115                    -0.068817      4.625      34.000
# 2   0.014901                     0.008539      6.250      34.000
# 3   0.024140                     0.024255      7.625      40.250
# 4  -0.028286                    -0.026887      8.500      39.375
# 5   0.088936                     0.091989     11.000      41.250
# 6  -0.004196                    -0.008886     12.625      44.750
# 7  -0.009405                    -0.005223     11.750      42.000
# 8  -0.091896                    -0.094314     11.750      37.000
# 9  -0.053843                    -0.051184      8.750      29.000
# 10 -0.012504                    -0.006698     10.625      30.750
# 11  0.065744                     0.059934     13.125      36.750
# 12  0.029513                     0.024828     18.500      43.000
#    Price..IBM Price..Microsoft Calendar.Date
# 1   98.625     92.50           19900131
# 2  103.875     98.75           19900228
# 3  106.125    110.75           19900330
# 4  109.000     58.00           19900430
# 5  120.000     73.00           19900531
# 6  117.500     76.00           19900629
# 7  111.500     66.50           19900731
# 8  101.875     61.50           19900831
# 9  106.375     63.00           19900928
# 10 105.375     63.75           19901031
# 11 113.625     72.25           19901130
# 12 113.000     75.25           19901231

# %% [markdown]
# To inspect only rows where the `Date` column is between 1991 (inclusive) and 1992 (exclusive), (i.e., observations from the year 1991), we reference `data[(data$Date >= 1991) & (data$Date < 1992),]`.  The row positions are again indicated by an expression, this time a complex expression using the AND operator (`&`) to get the intersection of 2 sets of row positions.  The column positions are blank and so assumed to be all columns.

# %%
data[(data$Date >= 1991) & (data$Date < 1992),]
# Out:
#    Date     Apple.Return Dell.Return IBM.Return  Microsoft.Return
# 13 1991.042  0.290698     0.22297297  0.12168141  0.30398670
# 14 1991.125  0.033694     0.11602210  0.02532544  0.05732484
# 15 1991.208  0.187773     0.12871288 -0.11553400  0.02289157
# 16 1991.292 -0.191176    -0.17982460 -0.09549940 -0.06713780
# 17 1991.375 -0.143273     0.05882353  0.04208738  0.10858586
# 18 1991.458 -0.117021    -0.01010100 -0.08480570 -0.06890660
# 19 1991.542  0.114458     0.17346939  0.04247104  0.07889909
# 20 1991.625  0.148541     0.13478261 -0.03125930  0.15986395
# 21 1991.708 -0.066038     0.02298851  0.06967742  0.04398827
# 22 1991.792  0.040404    -0.25468160 -0.05186970  0.05477528
# 23 1991.875 -0.012233    -0.05527640 -0.04620870  0.03595207
# 24 1991.958  0.110837     0.09042553 -0.03783780  0.14395887
#    Value.weighted.Market.Return SP.500.Return Price..Dell Price..Apple
# 13  0.049078                     0.041518     22.625      55.500
# 14  0.075847                     0.067281     25.250      57.250
# 15  0.028923                     0.022203     28.500      68.000
# 16  0.003322                     0.000346     23.375      55.000
# 17  0.040732                     0.038577     24.750      47.000
# 18 -0.044029                    -0.047893     24.500      41.500
# 19  0.046795                     0.044859     28.750      46.250
# 20  0.026819                     0.019649     32.625      53.000
# 21 -0.010975                    -0.019144     33.375      49.500
# 22  0.017789                     0.011860     24.875      51.500
# 23 -0.037275                    -0.043928     23.500      50.750
# 24  0.106778                     0.111588     25.625      56.375
#    Price..IBM Price..Microsoft Calendar.Date
# 13 126.750     98.125          19910131
# 14 128.750    103.750          19910228
# 15 113.875    106.125          19910328
# 16 103.000     99.000          19910430
# 17 106.125    109.750          19910531
# 18  97.125     68.125          19910628
# 19 101.250     73.500          19910731
# 20  96.875     85.250          19910830
# 21 103.625     89.000          19910930
# 22  98.250     93.875          19911031
# 23  92.500     97.250          19911129
# 24  89.000    111.250          19911231

# %% [markdown]
# As an alternative way to inspect only observations from the year 1991, we reference `data[!((data$Date < 1991) | (data$Date >= 1992)),]`.  The row positions are again indicated by an expression, this time a complex expression using the NOT operator (`!`) and the OR operator (`|`).  The column positions are blank and so assumed to be all columns.

# %%
data[!((data$Date < 1991) | (data$Date >= 1992)),]
# Out:
#    Date     Apple.Return Dell.Return IBM.Return  Microsoft.Return
# 13 1991.042  0.290698     0.22297297  0.12168141  0.30398670
# 14 1991.125  0.033694     0.11602210  0.02532544  0.05732484
# 15 1991.208  0.187773     0.12871288 -0.11553400  0.02289157
# 16 1991.292 -0.191176    -0.17982460 -0.09549940 -0.06713780
# 17 1991.375 -0.143273     0.05882353  0.04208738  0.10858586
# 18 1991.458 -0.117021    -0.01010100 -0.08480570 -0.06890660
# 19 1991.542  0.114458     0.17346939  0.04247104  0.07889909
# 20 1991.625  0.148541     0.13478261 -0.03125930  0.15986395
# 21 1991.708 -0.066038     0.02298851  0.06967742  0.04398827
# 22 1991.792  0.040404    -0.25468160 -0.05186970  0.05477528
# 23 1991.875 -0.012233    -0.05527640 -0.04620870  0.03595207
# 24 1991.958  0.110837     0.09042553 -0.03783780  0.14395887
#    Value.weighted.Market.Return SP.500.Return Price..Dell Price..Apple
# 13  0.049078                     0.041518     22.625      55.500
# 14  0.075847                     0.067281     25.250      57.250
# 15  0.028923                     0.022203     28.500      68.000
# 16  0.003322                     0.000346     23.375      55.000
# 17  0.040732                     0.038577     24.750      47.000
# 18 -0.044029                    -0.047893     24.500      41.500
# 19  0.046795                     0.044859     28.750      46.250
# 20  0.026819                     0.019649     32.625      53.000
# 21 -0.010975                    -0.019144     33.375      49.500
# 22  0.017789                     0.011860     24.875      51.500
# 23 -0.037275                    -0.043928     23.500      50.750
# 24  0.106778                     0.111588     25.625      56.375
#    Price..IBM Price..Microsoft Calendar.Date
# 13 126.750     98.125          19910131
# 14 128.750    103.750          19910228
# 15 113.875    106.125          19910328
# 16 103.000     99.000          19910430
# 17 106.125    109.750          19910531
# 18  97.125     68.125          19910628
# 19 101.250     73.500          19910731
# 20  96.875     85.250          19910830
# 21 103.625     89.000          19910930
# 22  98.250     93.875          19911031
# 23  92.500     97.250          19911129
# 24  89.000    111.250          19911231

# %% [markdown]
# To inspect only rows where the `Date` column is between 1991 (inclusive) and 1992 (exclusive), and only the `Date` and `Apple.Return` columns, we reference `data[(data\$Date >= 1991) & (data\$Date < 1992), c("Date", "Apple.Return")]`.

# %%
data[(data$Date >= 1991) & (data$Date < 1992), c("Date", "Apple.Return")]
# Out:
#    Date     Apple.Return
# 13 1991.042  0.290698
# 14 1991.125  0.033694
# 15 1991.208  0.187773
# 16 1991.292 -0.191176
# 17 1991.375 -0.143273
# 18 1991.458 -0.117021
# 19 1991.542  0.114458
# 20 1991.625  0.148541
# 21 1991.708 -0.066038
# 22 1991.792  0.040404
# 23 1991.875 -0.012233
# 24 1991.958  0.110837

# %% [markdown]
# ## More Extraction | First/Last/Random Few Rows

# %% [markdown]
# As a sometimes convenient alternative to referencing rows by their positions or using criteria, we can use the `head` and `tail` functions.
#
# To inspect the first 6 rows of data, we use `head(data)`.  The first parameter is the dataset, in this case `data`.  If no other parameters are provided, then the first 6 rows is assumed.

# %%
head(data)
# Out:
#   Date     Apple.Return Dell.Return IBM.Return  Microsoft.Return
# 1 1990.042 -0.035461    -0.1590909   0.04780877 0.06321839
# 2 1990.125  0.003235     0.3513514   0.06550063 0.06756756
# 3 1990.208  0.183824     0.2200000   0.02166065 0.12151898
# 4 1990.292 -0.021739     0.1147541   0.02709069 0.04740406
# 5 1990.375  0.050413     0.2941177   0.11201835 0.25862068
# 6 1990.458  0.084848     0.1477273  -0.02083330 0.04109589
#   Value.weighted.Market.Return SP.500.Return Price..Dell Price..Apple
# 1 -0.070115                    -0.068817      4.625      34.000
# 2  0.014901                     0.008539      6.250      34.000
# 3  0.024140                     0.024255      7.625      40.250
# 4 -0.028286                    -0.026887      8.500      39.375
# 5  0.088936                     0.091989     11.000      41.250
# 6 -0.004196                    -0.008886     12.625      44.750
#   Price..IBM Price..Microsoft Calendar.Date
# 1  98.625     92.50           19900131
# 2 103.875     98.75           19900228
# 3 106.125    110.75           19900330
# 4 109.000     58.00           19900430
# 5 120.000     73.00           19900531
# 6 117.500     76.00           19900629

# %% [markdown]
# To inspect the first 3 rows of data we use `head(data, 3)`.  The 2nd parameter is the number of rows.

# %%
head(data, 3)
# Out:
#   Date     Apple.Return Dell.Return IBM.Return Microsoft.Return
# 1 1990.042 -0.035461    -0.1590909  0.04780877 0.06321839
# 2 1990.125  0.003235     0.3513514  0.06550063 0.06756756
# 3 1990.208  0.183824     0.2200000  0.02166065 0.12151898
#   Value.weighted.Market.Return SP.500.Return Price..Dell Price..Apple
# 1 -0.070115                    -0.068817     4.625       34.00
# 2  0.014901                     0.008539     6.250       34.00
# 3  0.024140                     0.024255     7.625       40.25
#   Price..IBM Price..Microsoft Calendar.Date
# 1  98.625     92.50           19900131
# 2 103.875     98.75           19900228
# 3 106.125    110.75           19900330

# %% [markdown]
# To inspect the first 6 rows of the 2nd **through** 5th columns of data we use `head(data[,2:5])`.

# %%
head(data[,2:5])
# Out:
#   Apple.Return Dell.Return IBM.Return  Microsoft.Return
# 1 -0.035461    -0.1590909   0.04780877 0.06321839
# 2  0.003235     0.3513514   0.06550063 0.06756756
# 3  0.183824     0.2200000   0.02166065 0.12151898
# 4 -0.021739     0.1147541   0.02709069 0.04740406
# 5  0.050413     0.2941177   0.11201835 0.25862068
# 6  0.084848     0.1477273  -0.02083330 0.04109589

# %% [markdown]
# To inspect the first 6 rows of the 2nd **and** 5th columns of data we use `head(data[c(2,5)])`.

# %%
head(data[,c(2,5)])
# Out:
#   Apple.Return Microsoft.Return
# 1 -0.035461    0.06321839
# 2  0.003235    0.06756756
# 3  0.183824    0.12151898
# 4 -0.021739    0.04740406
# 5  0.050413    0.25862068
# 6  0.084848    0.04109589

# %% [markdown]
# To inspect the first 6 positions of the `Apple.Return` column of data we use `head(data$Apple.Return)`.

# %%
head(data$Apple.Return)
# Out:
# [1] -0.035461  0.003235  0.183824 -0.021739  0.050413  0.084848

# %% [markdown]
# To inspect the last 6 rows of data we use `tail(data)`.

# %%
tail(data)
# Out:
#     Date     Apple.Return Dell.Return IBM.Return Microsoft.Return
# 256 2011.292  0.004656     0.066161    0.046054   0.020874
# 257 2011.375 -0.006569     0.039431   -0.005276  -0.028935
# 258 2011.458 -0.034960     0.036692    0.015509   0.039584
# 259 2011.542  0.163285    -0.025795    0.060041   0.053846
# 260 2011.625 -0.014469    -0.084667   -0.050536  -0.023358
# 261 2011.708 -0.009121    -0.048772    0.017218  -0.064286
#     Value.weighted.Market.Return SP.500.Return Price..Dell Price..Apple
# 256  0.028683                     0.028495     15.470      350.13
# 257 -0.014934                    -0.013501     16.080      347.83
# 258 -0.018391                    -0.018258     16.670      335.67
# 259 -0.022448                    -0.021474     16.240      390.48
# 260 -0.057470                    -0.056791     14.865      384.83
# 261 -0.084872                    -0.071762     14.140      381.32
#     Price..IBM Price..Microsoft Calendar.Date
# 256 170.58     25.92            20110428
# 257 168.93     25.01            20110531
# 258 171.55     26.00            20110630
# 259 181.85     27.40            20110731
# 260 171.91     26.60            20110831
# 261 174.87     24.89            20110929

# %% [markdown]
# To inspect a random sample of 6 rows of data we use `data[sample(1:nrow(data), 6), ]`.

# %%
data[sample(1:nrow(data), 6), ]
# Out:
#     Date     Apple.Return Dell.Return IBM.Return  Microsoft.Return
# 25  1992.042  0.148559     0.2439024   0.01123596  0.08089887
# 110 1999.125 -0.154780    -0.1987500  -0.07246930 -0.14214290
# 10  1990.792  0.060345     0.2142857  -0.00940070  0.01190476
# 219 2008.208  0.147816     0.0010000   0.01124200  0.04338600
# 179 2004.875  0.279580     0.1557330   0.05203300  0.06864500
# 16  1991.292 -0.191176    -0.1798246  -0.09549940 -0.06713780
#     Value.weighted.Market.Return SP.500.Return Price..Dell Price..Apple
# 25  -0.001182                    -0.019900     31.875       64.7500
# 110 -0.038105                    -0.032283     80.125       34.8125
# 10  -0.012504                    -0.006698     10.625       30.7500
# 219 -0.010480                    -0.005960     19.920      143.5000
# 179  0.048210                     0.038595     40.520       67.0500
# 16   0.003322                     0.000346     23.375       55.0000
#     Price..IBM Price..Microsoft Calendar.Date
# 25   90.000    120.250          19920131
# 110 169.750    150.125          19990226
# 10  105.375     63.750          19901031
# 219 115.140     28.380          20080331
# 179  94.240     26.810          20041130
# 16  103.000     99.000          19910430

# %% [markdown]
# ## Row-wise Concatenation

# %%
data.new = data.frame(Date=c(2012.06,2012.10),
                      Apple.Return=c(0,0),
                      Dell.Return=c(0,0),
                      IBM.Return=c(0,0),
                      Microsoft.Return=c(0,0),
                      Value.weighted.Market.Return=c(0,0),
                      SP.500.Return=c(-0.07,-0.07),
                      Price..Dell=c(14.14,14.14),
                      Price..Apple=c(381.32,381.32),
                      Price..IBM=c(174.87,174.87),
                      Price..Microsoft=c(24.89,24.89),
                      Calendar.Date=c(20120131,20120228))

data.new
# Out:
#   Date    Apple.Return Dell.Return IBM.Return Microsoft.Return
# 1 2012.06 0            0           0          0
# 2 2012.10 0            0           0          0
#   Value.weighted.Market.Return SP.500.Return Price..Dell Price..Apple
# 1 0                            -0.07         14.14       381.32
# 2 0                            -0.07         14.14       381.32
#   Price..IBM Price..Microsoft Calendar.Date
# 1 174.87     24.89            20120131
# 2 174.87     24.89            20120228

# %%
datax = rbind(data, data.new)
datax
# Out:
#     Date     Apple.Return Dell.Return IBM.Return  Microsoft.Return
# 
# 256  0.028683                     0.028495     15.470      350.1300
# 257 -0.014934                    -0.013501     16.080      347.8300
# 258 -0.018391                    -0.018258     16.670      335.6700
# 259 -0.022448                    -0.021474     16.240      390.4800
# 260 -0.057470                    -0.056791     14.865      384.8300
# 261 -0.084872                    -0.071762     14.140      381.3200
# 262  0.000000                    -0.070000     14.140      381.3200
# 263  0.000000                    -0.070000     14.140      381.3200
#     Price..IBM Price..Microsoft Calendar.Date
# 1    98.625     92.500          19900131
# 2   103.875     98.750          19900228
# 3   106.125    110.750          19900330
# 4   109.000     58.000          19900430
# 5   120.000     73.000          19900531
# 6   117.500     76.000          19900629
# 7   111.500     66.500          19900731
# 8   101.875     61.500          19900831
# 9   106.375     63.000          19900928
# 10  105.375     63.750          19901031
# 11  113.625     72.250          19901130
# 12  113.000     75.250          19901231
# 13  126.750     98.125          19910131
# 14  128.750    103.750          19910228
# 15  113.875    106.125          19910328
# 16  103.000     99.000          19910430
# 17  106.125    109.750          19910531
# 18   97.125     68.125          19910628
# 19  101.250     73.500          19910731
# 20   96.875     85.250          19910830
# 21  103.625     89.000          19910930
# 22   98.250     93.875          19911031
# 23   92.500     97.250          19911129
# 24   89.000    111.250          19911231
# 25   90.000    120.250          19920131
# 26   86.875    123.500          19920228
# 27   83.500    118.500          19920331
# 28   90.750    110.250          19920430
# 29   90.750    121.000          19920529
# 30   97.875     70.000          19920630
# ... ...        ...              ...
# 234 104.42     23.7700          20090630
# 235 117.93     23.5200          20090731
# 236 118.05     24.6500          20090831
# 237 119.61     25.7200          20090929
# 238 120.61     27.7300          20091031
# 239 126.35     29.4100          20091130
# 240 130.90     30.4800          20091229
# 241 122.39     28.1800          20100131
# 242 127.16     28.6700          20100228
# 243 128.25     29.2875          20100331
# 244 129.00     30.5350          20100428
# 245 125.26     25.8000          20100531
# 246 123.48     23.0100          20100630
# 247 128.40     25.8100          20100731
# 248 123.13     23.4650          20100831
# 249 134.14     24.4900          20100929
# 250 143.60     26.6650          20101031
# 251 141.46     25.2575          20101130
# 252 146.76     27.9100          20101229
# 253 162.00     27.7250          20110131
# 254 161.88     26.5800          20110228
# 255 163.07     25.3900          20110331
# 256 170.58     25.9200          20110428
# 257 168.93     25.0100          20110531
# 258 171.55     26.0000          20110630
# 259 181.85     27.4000          20110731
# 260 171.91     26.6000          20110831
# 261 174.87     24.8900          20110929
# 262 174.87     24.8900          20120131
# 263 174.87     24.8900          20120228

# %%
# Use rbind to insert rows
datax = rbind(data[1,], data.new, data[2:nrow(data),])
datax
# Out:
#     Date     Apple.Return Dell.Return IBM.Return  Microsoft.Return
# 1   1990.042 -0.035461    -0.15909090  0.04780877  0.06321839
# 2   2012.060  0.000000     0.00000000  0.00000000  0.00000000
# 3   2012.100  0.000000     0.00000000  0.00000000  0.00000000
# 262 1990.125  0.003235     0.35135135  0.06550063  0.06756756
# 310 1990.208  0.183824     0.22000000  0.02166065  0.12151898
# 4   1990.292 -0.021739     0.11475410  0.02709069  0.04740406
# 253  0.019155                     0.022646     13.160      339.3200
# 254  0.038158                     0.031957     15.830      353.2100
# 255  0.003376                    -0.001047     14.510      348.5075
# 256  0.028683                     0.028495     15.470      350.1300
# 257 -0.014934                    -0.013501     16.080      347.8300
# 258 -0.018391                    -0.018258     16.670      335.6700
# 259 -0.022448                    -0.021474     16.240      390.4800
# 260 -0.057470                    -0.056791     14.865      384.8300
# 261 -0.084872                    -0.071762     14.140      381.3200
#     Price..IBM Price..Microsoft Calendar.Date
# 1    98.625     92.500          19900131
# 2   174.870     24.890          20120131
# 3   174.870     24.890          20120228
# 262 103.875     98.750          19900228
# 310 106.125    110.750          19900330
# 4   109.000     58.000          19900430
# 5   120.000     73.000          19900531
# 6   117.500     76.000          19900629
# 7   111.500     66.500          19900731
# 8   101.875     61.500          19900831
# 9   106.375     63.000          19900928
# 10  105.375     63.750          19901031
# 11  113.625     72.250          19901130
# 12  113.000     75.250          19901231
# 13  126.750     98.125          19910131
# 14  128.750    103.750          19910228
# 15  113.875    106.125          19910328
# 16  103.000     99.000          19910430
# 17  106.125    109.750          19910531
# 18   97.125     68.125          19910628
# 19  101.250     73.500          19910731
# 20   96.875     85.250          19910830
# 21  103.625     89.000          19910930
# 22   98.250     93.875          19911031
# 23   92.500     97.250          19911129
# 24   89.000    111.250          19911231
# 25   90.000    120.250          19920131
# 26   86.875    123.500          19920228
# 27   83.500    118.500          19920331
# 28   90.750    110.250          19920430
# ... ...        ...              ...
# 232 103.21     20.2600          20090428
# 233 106.28     20.8900          20090531
# 234 104.42     23.7700          20090630
# 235 117.93     23.5200          20090731
# 236 118.05     24.6500          20090831
# 237 119.61     25.7200          20090929
# 238 120.61     27.7300          20091031
# 239 126.35     29.4100          20091130
# 240 130.90     30.4800          20091229
# 241 122.39     28.1800          20100131
# 242 127.16     28.6700          20100228
# 243 128.25     29.2875          20100331
# 244 129.00     30.5350          20100428
# 245 125.26     25.8000          20100531
# 246 123.48     23.0100          20100630
# 247 128.40     25.8100          20100731
# 248 123.13     23.4650          20100831
# 249 134.14     24.4900          20100929
# 250 143.60     26.6650          20101031
# 251 141.46     25.2575          20101130
# 252 146.76     27.9100          20101229
# 253 162.00     27.7250          20110131
# 254 161.88     26.5800          20110228
# 255 163.07     25.3900          20110331
# 256 170.58     25.9200          20110428
# 257 168.93     25.0100          20110531
# 258 171.55     26.0000          20110630
# 259 181.85     27.4000          20110731
# 260 171.91     26.6000          20110831
# 261 174.87     24.8900          20110929

# %% [markdown]
# ## Column-wise Concatenation

# %%
data.ibm = read.csv("IBM.csv", header=TRUE) 
data.microsoft = read.csv("Microsoft.csv", header=TRUE)

# %%
data.ibm
# Out:
#     Date     IBM.Return  Price..IBM Calendar.Date
# 1   1990.042  0.04780877  98.625    19900131
# 2   1990.125  0.06550063 103.875    19900228
# 3   1990.208  0.02166065 106.125    19900330
# 4   1990.292  0.02709069 109.000    19900430
# 5   1990.375  0.11201835 120.000    19900531
# 6   1990.458 -0.02083330 117.500    19900629
#     Calendar.Date
# 1   19900131
# 2   19900228
# 3   19900330
# 4   19900430
# 5   19900531
# 6   19900629
# 7   19900731
# 8   19900831
# 9   19900928
# 10  19901031
# 11  19901130
# 12  19901231
# 13  19910131
# 14  19910228
# 15  19910328
# 16  19910430
# 17  19910531
# 18  19910628
# 19  19910731
# 20  19910830
# 21  19910930
# 22  19911031
# 23  19911129
# 24  19911231
# 25  19920131
# 26  19920228
# 27  19920331
# 28  19920430
# 29  19920529
# 30  19920630
# ... ...
# 232 20090428
# 233 20090531
# 234 20090630
# 235 20090731
# 236 20090831
# 237 20090929
# 238 20091031
# 239 20091130
# 240 20091229
# 241 20100131
# 242 20100228
# 243 20100331
# 244 20100428
# 245 20100531
# 246 20100630
# 247 20100731
# 248 20100831
# 249 20100929
# 250 20101031
# 251 20101130
# 252 20101229
# 253 20110131
# 254 20110228
# 255 20110331
# 256 20110428
# 257 20110531
# 258 20110630
# 259 20110731
# 260 20110831
# 261 20110929

# %% [markdown]
# ## Joins

# %%
data.apple = read.csv("Apple 2000-2005.csv", header=TRUE) 
data.dell  = read.csv("Dell 2001-2007.csv",  header=TRUE)

# %%
data.apple
# Out:
#     Date     Apple.Return Price..Apple Calendar.Date
# 1   2000.042  0.009119    103.7500     20000131
# 2   2000.125  0.104819    114.6250     20000229
# 3   2000.208  0.184842    135.8125     20000331
# 4   2000.292 -0.086516    124.0625     20000428
# 5   2000.375 -0.322922     84.0000     20000531
# 6   2000.458  0.247024     52.3750     20000630
# 7   2000.542 -0.029833     50.8125     20000731
# 8   2000.625  0.199262     60.9375     20000831
# 9   2000.708 -0.577436     25.7500     20000929
# 10  2000.792 -0.240291     19.5625     20001031
# 11  2000.875 -0.156550     16.5000     20001130
# 12  2000.958 -0.098485     14.8750     20001229
# 13  2001.042  0.453782     21.6250     20010131
# 14  2001.125 -0.156069     18.2500     20010228
# 15  2001.208  0.209315     22.0700     20010330
# 16  2001.292  0.154961     25.4900     20010430
# 17  2001.375 -0.217340     19.9500     20010531
# 18  2001.458  0.165413     23.2500     20010629
# 19  2001.542 -0.191828     18.7900     20010731
# 20  2001.625 -0.012773     18.5500     20010831
# 21  2001.708 -0.163881     15.5100     20010928
# 22  2001.792  0.132173     17.5600     20011031
# 23  2001.875  0.212984     21.3000     20011130
# 24  2001.958  0.028169     21.9000     20011231
# 25  2002.042  0.128767     24.7200     20020131
# 26  2002.125 -0.122168     21.7000     20020228
# 27  2002.208  0.090783     23.6700     20020328
# 28  2002.292  0.025349     24.2700     20020430
# 29  2002.375 -0.039967     23.3000     20020531
# 30  2002.458 -0.239485     17.7200     20020628
# ... ...      ...          ...          ...
# 43  2003.542  0.105981    21.0800      20030731
# 44  2003.625  0.072581    22.6100      20030829
# 45  2003.708 -0.083591    20.7200      20030930
# 46  2003.792  0.104730    22.8900      20031031
# 47  2003.875 -0.086501    20.9100      20031128
# 48  2003.958  0.021999    21.3700      20031231
# 49  2004.042  0.055685    22.5600      20040130
# 30 2003.458 20030630       0.061838    19.0600       0.014982   31.8400
# 31 2003.542 20030731       0.105981    21.0800       0.057789   33.6800
# 32 2003.625 20030829       0.072581    22.6100      -0.031473   32.6200
# 33 2003.708 20030930      -0.083591    20.7200       0.024525   33.4200
# 34 2003.792 20031031       0.104730    22.8900       0.077199   36.0000
# 35 2003.875 20031128      -0.086501    20.9100      -0.039722   34.5700
# 36 2003.958 20031231       0.021999    21.3700      -0.017067   33.9800
# 37 2004.042 20040130       0.055685    22.5600      -0.015892   33.4400
# 38 2004.125 20040227       0.060284    23.9200      -0.023624   32.6500
# 39 2004.208 20040331       0.130435    27.0400       0.029709   33.6200
# 40 2004.292 20040430      -0.046598    25.7800       0.034503   34.7800
# 41 2004.375 20040528       0.088441    28.0600       0.013226   35.2400
# 42 2004.458 20040630       0.159658    32.5400       0.016459   35.8200
# 43 2004.542 20040730      -0.006146    32.3400      -0.009771   35.4700
# 44 2004.625 20040831       0.066481    34.4900      -0.017762   34.8400
# 45 2004.708 20040930       0.123514    38.7500       0.021814   35.6000
# 46 2004.792 20041029       0.352258    52.4000      -0.015168   35.0600
# 47 2004.875 20041130       0.279580    67.0500       0.155733   40.5200
# 48 2004.958 20041231      -0.039523    64.4000       0.039980   42.1400
# 49 2005.042 20050131       0.194099    76.9000      -0.009018   41.7600
# 50 2005.125 20050228       0.166710    44.8600      -0.039990   40.0900
# 51 2005.208 20050331      -0.071110    41.6700      -0.041656   38.4200
# 52 2005.292 20050429      -0.134629    36.0600      -0.093441   34.8300
# 53 2005.375 20050531       0.102587    39.7593       0.146425   39.9300
# 54 2005.458 20050630      -0.074179    36.8100      -0.011771   39.4600
# 55 2005.542 20050729       0.158653    42.6500       0.025596   40.4700
# 56 2005.625 20050831       0.099414    46.8900      -0.120336   35.6000
# 57 2005.708 20050930       0.143314    53.6100      -0.039326   34.2000
# 58 2005.792 20051031       0.074240    57.5900      -0.067836   31.8800
# 59 2005.875 20051130       0.177635    67.8200      -0.054235   30.1510
# 60 2005.958 20051230       0.060012    71.8900      -0.006666   29.9500

# %% [markdown]
# ## Formatting

# %%
fmt(data[13,"Apple.Return"]) # output single value as a table, default title
# Out:
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:right;background-color: #FFFFFF !important;"> data[13, "Apple.Return"] </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:right;"> 0.290698 </td>
#   </tr>
# </tbody>
# </table>

# %%
fmt(data[13,"Apple.Return"], "apple return") # output single value as a table, title
# Out:
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:right;background-color: #FFFFFF !important;"> apple return </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:right;"> 0.290698 </td>
#   </tr>
# </tbody>
# </table>

# %%
fmt(data[13:18,1:5]) # default title, no row numbers
# Out:
# <table>
# <caption><center><font color="black"><b>data[13:18, 1:5]</b></font></center></caption>
#  <thead>
#   <tr>
#    <th style="text-align:right;background-color: #FFFFFF !important;"> Date </th>
#    <th style="text-align:right;background-color: #FFFFFF !important;"> Apple.Return </th>
#    <th style="text-align:right;background-color: #FFFFFF !important;"> Dell.Return </th>
#    <th style="text-align:right;background-color: #FFFFFF !important;"> IBM.Return </th>
#    <th style="text-align:right;background-color: #FFFFFF !important;"> Microsoft.Return </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:right;"> 1991.042 </td>
#    <td style="text-align:right;"> 0.290698 </td>
#    <td style="text-align:right;"> 0.2229730 </td>
#    <td style="text-align:right;"> 0.1216814 </td>
#    <td style="text-align:right;"> 0.3039867 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> 1991.125 </td>
#    <td style="text-align:right;"> 0.033694 </td>
#    <td style="text-align:right;"> 0.1160221 </td>
#    <td style="text-align:right;"> 0.0253254 </td>
#    <td style="text-align:right;"> 0.0573248 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> 1991.208 </td>
#    <td style="text-align:right;"> 0.187773 </td>
#    <td style="text-align:right;"> 0.1287129 </td>
#    <td style="text-align:right;"> -0.1155340 </td>
#    <td style="text-align:right;"> 0.0228916 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> 1991
</td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> 1991.458 </td>
#    <td style="text-align:right;"> -0.117021 </td>
#    <td style="text-align:right;"> -0.0101010 </td>
#    <td style="text-align:right;"> -0.0848057 </td>
#    <td style="text-align:right;"> -0.0689066 </td>
#   </tr>
# </tbody>
# </table></td><td style="background-color:white; vertical-align:top;"><table>
# <caption><center><font color="black"><b>1991 | 2nd Half</b></font></center></caption>
#  <thead>
#   <tr>
#    <th style="text-align:right;background-color: #FFFFFF !important;"> Date </th>
#    <th style="text-align:right;background-color: #FFFFFF !important;"> Apple.Return </th>
#    <th style="text-align:right;background-color: #FFFFFF !important;"> Dell.Return </th>
#    <th style="text-align:right;background-color: #FFFFFF !important;"> IBM.Return </th>
#    <th style="text-align:right;background-color: #FFFFFF !important;"> Microsoft.Return </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:right;"> 1991.542 </td>
#    <td style="text-align:right;"> 0.114458 </td>
#    <td style="text-align:right;"> 0.1734694 </td>
#    <td style="text-align:right;"> 0.0424710 </td>
#    <td style="text-align:right;"> 0.0788991 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> 1991.625 </td>
#    <td style="text-align:right;"> 0.148541 </td>
#    <td style="text-align:right;"> 0.1347826 </td>
#    <td style="text-align:right;"> -0.0312593 </td>
#    <td style="text-align:right;"> 0.1598640 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> 1991.708 </td>
#    <td style="text-align:right;"> -0.066038 </td>
#    <td style="text-align:right;"> 0.0229885 </td>
#    <td style="text-align:right;"> 0.0696774 </td>
#    <td style="text-align:right;"> 0.0439883 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> 1991.792 </td>
#    <td style="text-align:right;"> 0.040404 </td>
#    <td style="text-align:right;"> -0.2546816 </td>
#    <td style="text-align:right;"> -0.0518697 </td>
#    <td style="text-align:right;"> 0.0547753 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> 1991.875 </td>
#    <td style="text-align:right;"> -0.012233 </td>
#    <td style="text-align:right;"> -0.0552764 </td>
#    <td style="text-align:right;"> -0.0462087 </td>
#    <td style="text-align:right;"> 0.0359521 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> 1991.958 </td>
#    <td style="text-align:right;"> 0.110837 </td>
#    <td style="text-align:right;"> 0.0904255 </td>
#    <td style="text-align:right;"> -0.0378378 </td>
#    <td style="text-align:right;"> 0.1439589 </td>
#   </tr>
# </tbody>
# </table></td></tr></table>

# %% [markdown]
# ## More About R
#
# About strings:<br>
# A string is a sequence of characters meant to be interpretted as such, and not to be interpretted as a name.  A string is described by enclosing a sequence of characters within `"..."`.
#
# About comments:<br>
# A comment is text ignored by the R system, but perhaps useful to us.  A comment is described by the `#` symbol, followed by the comment text, through the end of the line.
#
# About functions:<br>
# A function is described by a function name, followed by parentheses that enclose the function's parameter values, separated by commas.  The parameters are distinguished either by their position or by explicitly naming them.  Named parameters are described by a parameter name, followed by the `=` symbol, followed by the parameter value.  An example function looks like this:<br>
# `melt(data, id=x)`
#
# About TRUE/FALSE values:<br>
# The R system recognizes the values `TRUE` and `FALSE`, and their abbreviations `T` and `F`.
#
# About function names; parameter names; and table, vector, and value names:<br>
# A name can include upper case and lower case letters - the upper case version of a letter is considered different than the lower case version of that letter.  A name can include numbers, but cannot start with a number.  A name can include the `.` and `_` characters.
#
# About output:<br>
# A table, vector, or value referenced on a line by itself will output the value assigned to it.

# %% [markdown]
# ## Further Reading
#
# * https://www.statmethods.net/management/subset.html

# %% [markdown]
# <p style="text-align:left; font-size:10px;">
# Copyright (c) Berkeley Data Analytics Group, LLC
# <span style="float:right;">
# Document revised July 17, 2020
# </span>
# </p>
