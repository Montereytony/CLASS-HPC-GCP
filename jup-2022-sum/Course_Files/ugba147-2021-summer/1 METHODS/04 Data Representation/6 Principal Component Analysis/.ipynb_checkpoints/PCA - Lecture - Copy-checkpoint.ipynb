# %% [markdown]
# # Principal Component Analysis $\,\, \tiny\text{Lecture}$
# <img src="banner lecture.jpg" align=left />

# %% [markdown]
# <br>
# ### Apparatus
# ___
# Load function libraries, define additional useful functions, and set defaults here.

# %%
options(warn=-1)

# Load some required functions
library(ggplot2,   verbose=FALSE, warn.conflicts=FALSE, quietly=TRUE)
library(gridExtra, verbose=FALSE, warn.conflicts=FALSE, quietly=TRUE)
library(rgl,       verbose=FALSE, warn.conflicts=FALSE, quietly=TRUE) # All rglwidget() calls must use elementID="myplot"
library(htmltools, verbose=FALSE, warn.conflicts=FALSE, quietly=TRUE)

# Set some visualization constants
restore = list(repr.plot.width=3, repr.plot.height=3)
PALETTE = c("#00A9FF", "#F8766D", "#7CAE00", "#C77CFF", "#CD9600", "#00BE67", "#FF61CC", "#00BFC4")
standard_arrow = arrow(angle=15, type="closed", length=unit(10, "points"))
theme.x_axis_only = theme(axis.title.y=element_blank(), axis.text.y=element_blank(), axis.ticks.y=element_blank(), panel.grid.major.y=element_blank(), panel.grid.minor.y=element_blank())

# Set some visualization formatting defaults
options(restore)
options(rgl.useNULL=TRUE)
update_geom_defaults("point", list(size=2, colour=PALETTE[3]))
update_geom_defaults("abline", list(color="black", size=0.15))
update_geom_defaults("hline", list(color="black", size=0.15))
update_geom_defaults("vline", list(color="black", size=0.15))
update_geom_defaults("col", list(fill=PALETTE[3]))
theme_update(plot.title=element_text(size=10, hjust=0.5), plot.subtitle=element_text(size=8, face="italic", hjust=0.5), axis.title=element_text(size=7), axis.text=element_text(size=7), strip.text=element_text(size=7), strip.text.y=element_text(angle=90), legend.title=element_blank(), legend.text=element_text(size=7))

# %% [markdown]
# <br>
# ### Principal Component Analysis Applied to 2 Variables
# ___

# %% [markdown]
# #### Retrieve and visualize the data.
#
# Note distributions of x and y variables.  There is more variation in x distribution than in y distribution.

# %%
data = data.frame(x=c(1, 2, 3, 6, 11, 14, 15, 16, 18), y=5*c(2.7, 2.3, 2.4, 2.8, 2.7, 3.2, 3.3, 3.25, 3.4)-5)
data
# Out:
#   x  y
# 1  1  8.50
# 2  2  6.50
# 3  3  7.00
# 4  6  9.00
# 5 11  8.50
# 6 14 11.00
# 7 15 11.50
# 8 16 11.25
# 9 18 12.00

# %%
ggplot(data) + geom_point(aes(x=x, y=y)) + xlim(0,20) + ylim(0,20)
# Out:
# plot without title

# %%
options(repr.plot.width=6, repr.plot.height=1)

p1 = ggplot(data) + geom_point(aes(x=x, y=0)) + xlim(0,20) + theme.x_axis_only
p2 = ggplot(data) + geom_point(aes(x=y, y=0)) + xlim(0,20) + theme.x_axis_only
grid.arrange(p1, p2, nrow=1)

options(restore)
# Out:
# plot without title

# %%
data.frame(variance_x=var(data$x), variance_y=var(data$y))
# Out:
#   variance_x variance_y
# 1 43.77778   4.131944

# %% [markdown]
# <br>
# #### Relative variation in variables.
#
# Calculate, show, and plot the relative variation in the variables.  The plot is called a **scree chart**.  The x variable accounts for 91% of the variation in the data, the y variable accounts for 9% of the variation in the data.

# %%
sdev = c(sd(data$x), sd(data$y))
scree = data.frame(axis=c("x", "y"), standard_deviation=sdev, variance=sdev^2, cum_variance=cumsum(sdev^2), proportion=sdev^2/sum(sdev^2))
scree

ggplot(scree) + geom_col(aes(x=axis, y=proportion)) + ylim(0,1)
# Out:
#   axis standard_deviation variance  cum_variance proportion
# 1 x    6.616478           43.777778 43.77778     0.91375562
# 2 y    2.032718            4.131944 47.90972     0.08624438
# plot without title

# %% [markdown]
# <br>
# #### Is there a way to view the data in a way to see even more separation in the relative variation?
#
# #### Principle components of the data.
#
# * **Think of prinicpal components as variables:**  an alternative set of variables that still capture exactly as much information and variation as the original variables do.  Each principal component's values are weighted sums of the original variables' values.
#
#
# * **Think of principal components as axes:**  an alternative set of orthogonal axes in the same space as the original axes, each going through the centroid of the data.  The values along the first principal component have the maximum variation possible as compared to any other orthogonal axis, the values along the second principal component have the next most variation, etc.

# %% [markdown]
# #### Visualize the principal components of the data.

# %%
pc = prcomp(data, retx=TRUE)

# %%
eigen.x.pc1 = pc$rotation["x","PC1"]
eigen.y.pc1 = pc$rotation["y","PC1"] 
eigen.x.pc2 = pc$rotation["x","PC2"]
eigen.y.pc2 = pc$rotation["y","PC2"] 
x1 = pc$center["x"]
y1 = pc$center["y"]
m.pc1 = eigen.y.pc1/eigen.x.pc1
m.pc2 = -1/m.pc1
i.pc1 = -m.pc1*x1 + y1
i.pc2 = -m.pc2*x1 + y1

ggplot(data) +
geom_point(aes(x=x, y=y)) +
geom_abline(aes(slope=m.pc1, intercept=i.pc1), color="blue") +
geom_abline(aes(slope=m.pc2, intercept=i.pc2), color="red") +
geom_segment(aes(x=x1, y=y1, xend=x1+5*eigen.x.pc1, yend=y1+5*eigen.y.pc1), arrow=standard_arrow, color="blue") +
geom_segment(aes(x=x1, y=y1, xend=x1+3*eigen.x.pc2, yend=y1+3*eigen.y.pc2), arrow=standard_arrow, color="red") +
geom_point(aes(x=x1, y=y1), size=1, color="black") +
xlim(0,20) + ylim(0,20)
# Out:
# plot without title

# %% [markdown]
# #### Visualize the tranformed data.
#
# Shift the centroid of the data to the origin (0,0).  Rotate the data such that the principal components align with original axes.  The transformed data are called **scores**.

# %%
ggplot(as.data.frame(pc$x)) +
geom_point(aes(x=PC1, y=PC2)) +
geom_hline(aes(yintercept=0), color="blue") +
geom_vline(aes(xintercept=0), color="red") +
geom_segment(aes(x=0, y=0, xend=5*1, yend=0), arrow=standard_arrow, color="blue") +
geom_segment(aes(x=0, y=0, xend=0, yend=3*1), arrow=standard_arrow, color="red") +
geom_point(aes(x=0, y=0), size=1, color="black") +
xlim(-10,10) + ylim(-10,10)
# Out:
# plot without title

# %% [markdown]
# <br>
# #### How to tranform data to principal component scores: step 1
#
# Use `mean` function to calculate the centroid of the data.

# %%
as.data.frame(pc$center)
# Out:
#   pc$center
# x 9.555556
# y 9.472222

# %% [markdown]
# <br>
# #### How to tranform data from original representation to principal component scores: step 2
#
# Use a function like `prcomp` to calculate the weight table.

# %%
as.data.frame(pc$rotation)
# Out:
#   PC1       PC2
# x 0.9620138 -0.2730009
# y 0.2730009  0.9620138

# %% [markdown]
# <br>
# #### How to tranform data from original representation to principal component scores:  step 3
#
# For each observation, use this formula to calculate a score based on centroid and weight table ...
#
# <table align="left" width="500">
#   <tr>
#     <td width="10">  $x \\ y$ </td>
#     <td width="10">  $\large \rightarrow$ </td>
#     <td width="300"> $PC1 = \left ( weight_{x,PC1} \times (x - centroid_x) \right ) + \left ( weight_{y,PC1} \times (y - centroid_y) \right ) \\
#                       PC2 = \left ( weight_{x,PC2} \times (x - centroid_x) \right ) + \left ( weight_{y,PC2} \times (y - centroid_y) \right )$ </td>
#   </tr>
# </table>

# %% [markdown]
# For example ...
#
# <table align="left" width="700">
#   <tr>
#     <td width="50">  $x=1 \\y=8.5$ </td>
#     <td width="30">  $\large \rightarrow$ </td>
#     <td width="400"> $PC1 = \big ( 0.9620138 \times (1 - 9.555556) \big ) +  \big ( 0.2730009 \times (8.5 - 9.472222) \big ) = -8.49598 \\
#                       PC2 = \big ( -0.2730009 \times (1 - 9.555556) \big ) +  \big ( 0.9620138 \times (8.5  - 9.472222) \big ) = 1.400383$  </td>
#   </tr>
# </table>

# %%
PC1.point_1 = pc$rotation["x","PC1"]*(data$x[1]-pc$center["x"]) + pc$rotation["y", "PC1"]*(data$y[1]-pc$center["y"]) 
PC2.point_1 = pc$rotation["x","PC2"]*(data$x[1]-pc$center["x"]) + pc$rotation["y", "PC2"]*(data$y[1]-pc$center["y"]) 
data.frame(PC1=PC1.point_1, PC2=PC2.point_1, row.names=NULL)
# Out:
#   PC1      PC2
# 1 -8.49598 1.400383

# %% [markdown]
# <br>
# #### Transformed data in terms of principal component scores.

# %%
as.data.frame(pc$x)
# Out:
#   PC1       PC2
# 1 -8.495980  1.40038297
# 2 -8.079968 -0.79664548
# 3 -6.981454 -0.58863946
# 4 -3.549411  0.51638549
# 5  1.124158 -1.32962578
# 6  4.692701  0.25640606
# 7  5.791216  0.46441208
# 8  6.684979 -0.04909224
# 9  8.813758  0.12641635

# %%
options(repr.plot.width=6, repr.plot.height=1)

p1 = ggplot(as.data.frame(pc$x)) + geom_point(aes(x=PC1, y=0)) + xlim(-10,10) + theme.x_axis_only
p2 = ggplot(as.data.frame(pc$x)) + geom_point(aes(x=PC2, y=0)) + xlim(-10,10) + theme.x_axis_only
grid.arrange(p1, p2, nrow=1)

options(restore)
# Out:
# plot without title

# %%
data.frame(variance_PC1=var(as.data.frame(pc$x)$PC1), variance_PC2=var(as.data.frame(pc$x)$PC2))
# Out:
#   variance_PC1 variance_PC2
# 1 47.25015     0.6595732

# %% [markdown]
# <br>
# #### Relative variation in prinicipal components.
#
# Calculate, show, and plot the relative variation in the principal components.  The PC1 prinicpal component accounts for 99% of the variation in the data, the PC2 prinicipal component accounts for 1% of the variation in the data.
#
# Note that the separation of variance is greater in the principal components than in the original representation.

# %%
scree = data.frame(axis=c("PC1", "PC2"), standard_deviation=pc$sdev, variance=pc$sdev^2, cum_variance=cumsum(pc$sdev^2), proportion=pc$sdev^2/sum(pc$sdev^2), cum_proportion=cumsum(pc$sdev^2/sum(pc$sdev^2)))
scree

ggplot(scree) + geom_col(aes(x=axis, y=proportion)) + ylim(0,1)
# Out:
#   axis standard_deviation variance   cum_variance proportion cum_proportion
# 1 PC1  6.8738744          47.2501491 47.25015     0.986233   0.986233
# 2 PC2  0.8121411           0.6595732 47.90972     0.013767   1.000000
# plot without title

# %% [markdown]
# <br>
# ### Principal Component Analysis Applied to 2 Variables (normalized)
# ___

# %%
data.norm = as.data.frame(scale(data))
data.norm
# Out:
#   x          y
# 1 -1.2930680 -0.4782867
# 2 -1.1419302 -1.4621908
# 3 -0.9907924 -1.2162148
# 4 -0.5373789 -0.2323107
# 5  0.2183102 -0.4782867
# 6  0.6717236  0.7515934
# 7  0.8228614  0.9975694
# 8  0.9739993  0.8745814
# 9  1.2762749  1.2435454

# %%
ggplot(data.norm) + geom_point(aes(x=x, y=y)) + xlim(-2.5,2.5) + ylim(-2.5,2.5)
# Out:
# plot without title

# %%
options(repr.plot.width=6, repr.plot.height=1)

p1 = ggplot(data.norm) + geom_point(aes(x=x, y=0)) + xlim(-2.5,2.5) + theme.x_axis_only
p2 = ggplot(data.norm) + geom_point(aes(x=y, y=0)) + xlim(-2.5,2.5) + theme.x_axis_only
grid.arrange(p1, p2, nrow=1)

options(restore)
# Out:
# plot without title

# %%
sdev = c(sd(data.norm$x), sd(data.norm$y))
scree = data.frame(axis=c("x", "y"), standard_deviation=sdev, variance=sdev^2, cum_variance=cumsum(sdev^2), proportion=sdev^2/sum(sdev^2), cum_proportion=cumsum(sdev^2/sum(sdev^2)))
scree

ggplot(scree) + geom_col(aes(x=axis, y=proportion)) + ylim(0,1)
# Out:
#   axis standard_deviation variance cum_variance proportion cum_proportion
# 1 x    1                  1        1            0.5        0.5
# 2 y    1                  1        2            0.5        1.0
# plot without title

# %%
pc.norm = prcomp(data.norm, retx=TRUE)

as.data.frame(pc.norm$center)
as.data.frame(pc.norm$rotation)
as.data.frame(pc.norm$x)
# Out:
#   pc.norm$center
# x 4.934325e-17
# y 3.885781e-16
#   PC1       PC2
# x 0.7071068 -0.7071068
# y 0.7071068  0.7071068
#   PC1        PC2
# 1 -1.2525369  0.57613737
# 2 -1.8413916 -0.22645845
# 3 -1.5605897 -0.15939771
# 4 -0.5442527  0.21571581
# 5 -0.1838312 -0.49256838
# 6  1.0064371  0.05647645
# 7  1.2872390  0.12353719
# 8  1.3071439 -0.07029905
# 9  1.7817820 -0.02314323

# %%
eigen.x.pc1 = pc.norm$rotation["x","PC1"]
eigen.y.pc1 = pc.norm$rotation["y","PC1"] 
eigen.x.pc2 = pc.norm$rotation["x","PC2"]
eigen.y.pc2 = pc.norm$rotation["y","PC2"] 
x1 = pc.norm$center["x"]
y1 = pc.norm$center["y"]
m.pc1 = eigen.y.pc1/eigen.x.pc1
m.pc2 = -1/m.pc1
i.pc1 = -m.pc1*x1 + y1
i.pc2 = -m.pc2*x1 + y1

ggplot(data.norm) +
geom_point(aes(x=x, y=y)) +
geom_abline(aes(slope=m.pc1, intercept=i.pc1), color="blue") +
geom_abline(aes(slope=m.pc2, intercept=i.pc2), color="red") +
geom_segment(aes(x=x1, y=y1, xend=x1+eigen.x.pc1, yend=y1+eigen.y.pc1), arrow=standard_arrow, color="blue") +
geom_segment(aes(x=x1, y=y1, xend=x1+0.6*eigen.x.pc2, yend=y1+0.6*eigen.y.pc2), arrow=standard_arrow, color="red") +
geom_point(aes(x=x1, y=y1), size=1, color="black") +
xlim(-2.5,2.5) + ylim(-2.5,2.5)
# Out:
# plot without title

# %%
ggplot(as.data.frame(pc.norm$x)) +
geom_point(aes(x=PC1, y=PC2)) +
geom_hline(aes(yintercept=0), color="blue") +
geom_vline(aes(xintercept=0), color="red") +
geom_segment(aes(x=0, y=0, xend=1, yend=0), arrow=standard_arrow, color="blue") +
geom_segment(aes(x=0, y=0, xend=0, yend=0.6*1), arrow=standard_arrow, color="red") +
geom_point(aes(x=0, y=0), size=1, color="black") +
xlim(-2.5,2.5) + ylim(-2.5,2.5)
# Out:
# plot without title

# %%
options(repr.plot.width=6, repr.plot.height=1)

p1 = ggplot(as.data.frame(pc.norm$x)) + geom_point(aes(x=PC1, y=0)) + xlim(-2.5,2.5) + theme.x_axis_only
p2 = ggplot(as.data.frame(pc.norm$x)) + geom_point(aes(x=PC2, y=0)) + xlim(-2.5,2.5) + theme.x_axis_only
grid.arrange(p1, p2, nrow=1)

options(restore)
# Out:
# plot without title

# %%
scree = data.frame(axis=c("PC1", "PC2"), standard_deviation=pc.norm$sdev, variance=pc.norm$sdev^2, cum_variance=cumsum(pc.norm$sdev^2), proportion=pc.norm$sdev^2/sum(pc.norm$sdev^2), cum_proportion=cumsum(pc.norm$sdev^2/sum(pc.norm$sdev^2)))
scree

ggplot(scree) + geom_col(aes(x=axis, y=proportion)) + ylim(0,1)
# Out:
#   axis standard_deviation variance   cum_variance proportion cum_proportion
# 1 PC1  1.3819501          1.90978615 1.909786     0.95489307 0.9548931
# 2 PC2  0.3003562          0.09021385 2.000000     0.04510693 1.0000000
# plot without title

# %% [markdown]
# <br>
# ### Principal Component Analysis Applied to 3 Variables (normalized)
# ___

# %%
data.ext = cbind(data, data.frame(z=c(1, 2, 10, 13, 16, 15, 4, 8, 6)))
data.ext
# Out:
#   x  y     z
# 1  1  8.50  1
# 2  2  6.50  2
# 3  3  7.00 10
# 4  6  9.00 13
# 5 11  8.50 16
# 6 14 11.00 15
# 7 15 11.50  4
# 8 16 11.25  8
# 9 18 12.00  6

# %%
p = open3d(); view3d(0,0, zoom=0.65)

plot3d(data.ext, type="s", col=PALETTE[3], xlim=c(0,20), ylim=c(0,20), zlim=c(0,20))

grid3d(c("x","y","z"))

rglwidget(elementId="myplot", width=400, height=400)
rgl.close()
# Out:
# Loading required namespace: rmarkdown
# HTML widgets cannot be represented in plain text (need html)

# %%
options(repr.plot.width=9, repr.plot.height=1)

p1 = ggplot(data.ext) + geom_point(aes(x=x, y=0)) + xlim(0,20) + theme.x_axis_only
p2 = ggplot(data.ext) + geom_point(aes(x=y, y=0)) + xlim(0,20) + theme.x_axis_only
p3 = ggplot(data.ext) + geom_point(aes(x=z, y=0)) + xlim(0,20) + theme.x_axis_only
grid.arrange(p1, p2, p3, nrow=1)

options(restore)
# Out:
# plot without title

# %%
sdev = c(sd(data.ext$x), sd(data.ext$y), sd(data.ext$z))
scree = data.frame(axis=c("x", "y", "z"), standard_deviation=sdev, variance=sdev^2, cum_variance=cumsum(sdev^2), proportion=sdev^2/sum(sdev^2), cum_proportion=cumsum(sdev^2/sum(sdev^2)))
scree

ggplot(scree) + geom_col(aes(x=axis, y=proportion)) + ylim(0,1)
# Out:
#   axis standard_deviation variance  cum_variance proportion cum_proportion
# 1 x    6.616478           43.777778 43.77778     0.55654631 0.5565463
# 2 y    2.032718            4.131944 47.90972     0.05252935 0.6090757
# 3 z    5.545268           30.750000 78.65972     0.39092434 1.0000000
# plot without title

# %%
pc.ext = prcomp(data.ext, retx=TRUE)

as.data.frame(pc.ext$center)
as.data.frame(pc.ext$rotation)
as.data.frame(pc.ext$x)
# Out:
#   pc.ext$center
# x 9.555556
# y 9.472222
# z 8.333333
#   PC1       PC2        PC3
# x 0.8772226 -0.3861667  0.28522935
# y 0.2333815 -0.1761802 -0.95629160
# z 0.4195397  0.9054479 -0.06442508
#   PC1        PC2       PC3
# 1 -10.808650 -3.164794 -1.0381170
# 2  -9.978651 -2.293153  1.0952704
# 3  -5.628420  4.476173  0.3869534
# 4  -1.271370  5.681657 -0.8632170
# 5   4.256672  6.555257  0.8478003
# 6   7.052254  4.050859 -0.6228156
# 7   3.431230 -6.383325 -0.1070562
# 8   5.928266 -3.103655  0.1595458
# 9   7.018668 -5.819019  0.1416359

# %%
eigen.x.pc1 = pc.ext$rotation["x","PC1"]
eigen.y.pc1 = pc.ext$rotation["y","PC1"] 
eigen.z.pc1 = pc.ext$rotation["z","PC1"] 
eigen.x.pc2 = pc.ext$rotation["x","PC2"]
eigen.y.pc2 = pc.ext$rotation["y","PC2"]
eigen.z.pc2 = pc.ext$rotation["z","PC2"]
eigen.x.pc3 = pc.ext$rotation["x","PC3"]
eigen.y.pc3 = pc.ext$rotation["y","PC3"]
eigen.z.pc3 = pc.ext$rotation["z","PC3"]

x1 = pc.ext$center["x"]
y1 = pc.ext$center["y"]
z1 = pc.ext$center["z"]

center = data.frame(x=x1, y=y1, z=z1)

p = open3d(); view3d(0,0, zoom=0.65)

plot3d(data.ext, type="s", col=PALETTE[3], xlim=c(0,20), ylim=c(0,20), zlim=c(0,20))
spheres3d(center, type="s", radius=0.75, add=TRUE)
abclines3d(x1, y1, z1, eigen.x.pc1, eigen.y.pc1, eigen.z.pc1, color="blue", add=TRUE)
abclines3d(x1, y1, z1, eigen.x.pc2, eigen.y.pc2, eigen.z.pc2, color="red", add=TRUE)
abclines3d(x1, y1, z1, eigen.x.pc3, eigen.y.pc3, eigen.z.pc3, color="violet", add=TRUE)
arrow3d(p0=c(x1,y1,z1), p1=c(x1+7*eigen.x.pc1,y1+7*eigen.y.pc1,z1+7*eigen.z.pc1), type="rotation", color="blue", add=TRUE)
arrow3d(p0=c(x1,y1,z1), p1=c(x1+5*eigen.x.pc2,y1+5*eigen.y.pc2,z1+5*eigen.z.pc2), type="rotation", color="red", add=TRUE)
arrow3d(p0=c(x1,y1,z1), p1=c(x1+3*eigen.x.pc3,y1+3*eigen.y.pc3,z1+3*eigen.z.pc3), type="rotation", color="violet", add=TRUE)

grid3d(c("x","y","z"))

rglwidget(elementId="myplot", width=400, height=400)
rgl.close()
# Out:
# HTML widgets cannot be represented in plain text (need html)

# %%
options(repr.plot.width=9, repr.plot.height=1)

p1 = ggplot(as.data.frame(pc.ext$x)) + geom_point(aes(x=PC1, y=0)) + xlim(-10,10) + theme.x_axis_only
p2 = ggplot(as.data.frame(pc.ext$x)) + geom_point(aes(x=PC2, y=0)) + xlim(-10,10) + theme.x_axis_only
p3 = ggplot(as.data.frame(pc.ext$x)) + geom_point(aes(x=PC3, y=0)) + xlim(-10,10) + theme.x_axis_only
grid.arrange(p1, p2, p3, nrow=1)

options(restore)
# Out:
# plot without title

# %%
scree = data.frame(axis=c("PC1", "PC2", "PC3"), standard_deviation=pc.ext$sdev, variance=pc.ext$sdev^2, cum_variance=cumsum(pc.ext$sdev^2), proportion=pc.ext$sdev^2/sum(pc.ext$sdev^2), cum_proportion=cumsum(pc.ext$sdev^2/sum(pc.ext$sdev^2)))
scree

ggplot(scree) + geom_col(aes(x=axis, y=proportion)) + ylim(0,1)
# Out:
#   axis standard_deviation variance   cum_variance proportion  cum_proportion
# 1 PC1  7.1913906          51.7160990 51.71610     0.657466077 0.6574661
# 2 PC2  5.1382532          26.4016454 78.11774     0.335643767 0.9931098
# 3 PC3  0.7361914           0.5419778 78.65972     0.006890156 1.0000000
# plot without title

# %% [markdown]
# <br>
# ### Further Reading
#
# * https://stats.stackexchange.com/questions/2691/making-sense-of-principal-component-analysis-eigenvectors-eigenvalues
# * https://www.researchgate.net/publication/281042621_The_Selection_of_Winning_Stocks_Using_Principal_Component_Analysis
# * https://stats.stackexchange.com/questions/133149/why-is-variance-instead-of-standard-deviation-the-default-measure-of-informati
# * http://www.indiana.edu/~g562/PBDB2013/Day%203B%20-%20PCA%20and%20morphospace.pdf

# %% [markdown]
# $\tiny \text{Copyright (c) Berkeley Data Analytics Group, LLC}$
