# %% [markdown]
# # Data Analytics for Business Decisions: Applications

# %%
f = "setup.R"; for (i in 1:10) { if (file.exists(f)) break else f = paste0("../", f) }; source(f)
# Out:
# <p style="text-align:center; font-size:10px;">
# .................................................... start of document ....................................................
# </p>

# %% [markdown]
# ## Table of Contents

# %%
fmt.toc(gather.toc(root=".", hide="Table of Contents"))
# Out:
# 01 Fundraising Strategies<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;01-Fundraising Strategies CA<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;01-Fundraising Strategies TX<br><br>02 Iowa Liquor Sales Trends<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;02-1 Iowa Liquor Sales Trends 2013-2016<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;02-2 Iowa Liquor Sales Trends 2017-2020<br><br>03 Lending Tree Loan Portfolio<br><br>04 Fortune 500 Diversity<br><br>05 NCHS Market Segmentation<br><br>06 Lending Tree Loan Portfolio Revisited<br><br>07 SATO Customer Churn Intervention<br><br>08 Scania Trucks Predictive Maintenance<br><br>09 Credit Card Fraud Detection<br><br>10 Call Center Scheduling<br><br>11 Hotel Deceptive Reviews<br><br>13 Targeted Marketing<br><br>More Case Studies In Progress<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Airlines<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Boeing<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;CER Electricity Demand<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Francis Bacon<br>&nbsp;&nbsp;&nbsp
# ...

# %% [markdown]
# ## Table of Contents - Detailed

# %%
fmt.toc(gather.toc(root=".", hide="Table of Contents"), detail=TRUE)
# Out:
# <b>01 Fundraising Strategies</b><br><br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<b>01-Fundraising Strategies CA</b><br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;1 Situation<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;2 Data<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;2.1 Retrieve Raw Data<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;2.1.1 Candidates<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;2.1.2 Candidate/Committee Associations<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;2.1.3 Donations<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&n
# ...

# %% [markdown]
# ## R Packages
#
# This book presents R code based on the following system environment and R package versions.

# %%
sessionInfo()
# Out:
# R version 3.6.1 (2019-07-05)
# Platform: x86_64-w64-mingw32/x64 (64-bit)
# Running under: Windows 10 x64 (build 19041)
#
# Matrix products: default
#
# locale:
# [1] LC_COLLATE=English_United States.1252
# [2] LC_CTYPE=English_United States.1252
# [3] LC_MONETARY=English_United States.1252
# [4] LC_NUMERIC=C
# [5] LC_TIME=English_United States.1252
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
#  [1] tm_0.7-6          SnowballC_0.6.0   stringr_1.4.0     rpart.plot_3.0.8
#  [5] rpart_4.1-15      rmarkdown_1.13    rjson_0.2.20      rgl_0.100.24
#  [9] reshape2_1.4.3    readxl_1.3.1      qgraph_1.6.3      psych_1.8.12
# [13] polyclip_1.10-0   pracma_2.2.5      NLP_0.2-0         neuralnet_1.44.2
# [17] mvtnorm_1.0-11    mclust_5.4.5      MASS_7.3-51.4     lubridate_1.7.4
# [21] knitr_1.23        ks_1.11.5         kknn_1.3.1        kableExtra_1.1.0
# ...

# %%
# library(IRdisplay, verbose=FALSE, warn.conflicts=FALSE, quietly=TRUE)
# library(plyr,      verbose=FALSE, warn.conflicts=FALSE, quietly=TRUE)

# pretty = function(text=NULL, position="left")
#   { text.formatted = paste0("<", position, "><font size=\"2\" color=\"black\">", text, "</font></", position, ">")
#     display_html(as.character(text.formatted)) }

# toc = function(d, indent=0, html=TRUE)
#   { space = if (html) "&nbsp;" else " "
#     newline = if (html) "<br/>" else "\n"
#     s = split(d, d[,1], drop=TRUE)
#     x = ""  
#     for (i in names(s))
#       { x = paste0(x, paste(rep(space,indent),collapse=""), i, newline)
#         if (nrow(s[[i]])>1) x = paste0(x, toc(s[[i]][,-1,drop=FALSE], indent=indent+4, html)) }
#     return(x) }

# f = sub("\\.ipynb", "", list.files("../..", recursive=TRUE, pattern="*.ipynb"))
# fo = grep("Old", f, invert=TRUE, value=TRUE)
# l = strsplit(fo, "/")
# p = llply(l, function(x) if (sub("^[0-9\\.]* ", "", x[length(x)-1]) == x[length(x)]) head(x,-1) else x)    
# depth = max(laply(p, length))
# d = data.frame(laply(p, function(x) x[1]))
# for (i in 2:depth) { d = cbind(d, laply(p, function(x) x[i])) }
                                        
# pretty(toc(d))

# %% [markdown]
# <p style="text-align:left; font-size:10px;">
# Copyright (c) Berkeley Data Analytics Group, LLC
# <span style="float:right;">
# Document revised January 7, 2021
# </span>
# </p>
